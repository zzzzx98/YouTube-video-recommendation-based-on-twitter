# %%
import findspark
findspark.init()
from pyspark import SparkContext
sc = SparkContext()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in c:\programdata\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from ipython-autotime) (7.19.0)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (5.0.5)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.17.1)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (2.7.2)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython->ipython-autotime) (50.3.1.post20201107)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.10->ipython->ipython-autotime) (0.7.0)
# time: 0 ns (started: 2022-05-03 10:36:00 -04:00)

# %%
# sc.stop()
# Out:
# time: 0 ns (started: 2022-05-03 10:36:00 -04:00)

# %%
import re
import numpy as np
import pandas as pd
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
# nltk.download('words')
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# nltk.download('wordnet')
# Out:
# time: 1.19 s (started: 2022-05-03 10:36:00 -04:00)

# %% [markdown]
# ## Data Preparation

# %%
txt_df = spark.read.csv(
    "data_test.csv", 
    header=True,
    inferSchema = True
)
txt_df.show(3)
# Out:
# +-------------------+-------------------+--------------------+----------+--------+--------+---------+--------------+-----------------+-----+--------------------+--------+--------+----+------+-------------+--------------+-----------+--------+--------+--------------------+-------+---------+-----+---------+----+----+------+----------+-------+----------+--------+------------+---------+---------+----------+
# |                 id|    conversation_id|          created_at|      date|    time|timezone|  user_id|      username|             name|place|               tweet|language|mentions|urls|photos|replies_count|retweets_count|likes_count|hashtags|cashtags|                link|retweet|quote_url|video|thumbnail|near| geo|source|user_rt_id|user_rt|retweet_id|reply_to|retweet_date|translate|trans_src|trans_dest|
# +-------------------+-------------------+--------------------+----------+--------+--------+---------+--------------+-----------------+-----+--------------------+--------+--------+----+------+-------------+--------------+-----------+--------+--------+--------------------+-------+---------+-----+---------+----+----+------+----------+-------+----------+--------+------------+---------+---------+----------+
# |1477099571201200130|1477099571201200130|2021-12-31 21:09:...|2021-12-31|21:09:15|    -400|215231197|palomahepzibah|mimi sanson viola| null|Stay gold, Pony Boy.|      en|      []|  []|    []|            0|             0|          0|      []|      []|https://twitter.c...|  False|     null|    0|     null|null|null|  null|      null|   null|      null|      []|        null|     null|     null|      null|
# |1477088892813660161|1477088892813660161|2021-12-31 20:26:...|2021-12-31|20:26:49|    -400|215231197|palomahepzibah|mimi sanson viola| null|your tone gives y...|      en|      []|  []|    []|            0|             0|          1|      []|      []|https://twitter.c...|  False|     null|    0|     null|null|null|  null|      null|   null|      null|      []|        null|     null|     null|      null|
# |1476754149144686592|1476754149144686592|2021-12-30 22:16:...|2021-12-30|22:16:40|    -400|215231197|palomahepzibah|mimi sanson viola| null|This unbelieving ...|      en|      []|  []|    []|            0|             0|          0|      []|      []|https://twitter.c...|  False|     null|    0|     null|null|null|  null|      null|   null|      null|      []|        null|     null|     null|      null|
# +-------------------+-------------------+--------------------+----------+--------+--------+---------+--------------+-----------------+-----+--------------------+--------+--------+----+------+-------------+--------------+-----------+--------+--------+--------------------+-------+---------+-----+---------+----+----+------+----------+-------+----------+--------+------------+---------+---------+----------+
# only showing top 3 rows
#
# time: 4.47 s (started: 2022-05-03 10:36:01 -04:00)

# %%
temp = txt_df.select('user_id', 'tweet')
txt_row = temp.rdd
txt = txt_row.map(lambda x: [str(x[0]), x[1]])
txt.take(2)
# Out:
# [['215231197', 'Stay gold, Pony Boy.'],
#  ['215231197', 'your tone gives you away.']]
# time: 687 ms (started: 2022-05-03 10:36:06 -04:00)

# %% [markdown]
# ## Data Pre-processing

# %%
def easy_clean(txt):
    
    # transform to lowercase
    txt_low = txt.lower()
    
    # remove punctuations and numbers except for #
    txt_clean = re.sub("[^#_a-zA-Z]", " ",txt_low)
    
    return txt_clean


def extract_hash_words(txt_clean):
    
    # find all hash words (with hash symbol)
    txt_hash_words = re.findall(r'#\w+',txt_clean)
    
    # remove the hash symbol
    txt_nohash_words_txt = re.sub("#", " ", " ".join([x for x in txt_hash_words]))
    
    # tokenize
    txt_nohash_words = txt_nohash_words_txt.split()
    
    return txt_nohash_words
# Out:
# time: 0 ns (started: 2022-05-03 10:36:07 -04:00)

# %%
# clean each tweet in a simple way
txt_clean_tweet = txt.map(lambda x: (x[0],easy_clean(x[1]),x[1]))
txt_clean_tweet.take(50)
# Out:
# [('215231197', 'stay gold  pony boy ', 'Stay gold, Pony Boy.'),
#  ('215231197', 'your tone gives you away ', 'your tone gives you away.'),
#  ('215231197',
#   'this unbelieving world has nowhere to rest its weary head ',
#   'This unbelieving world has nowhere to rest its weary head.'),
#  ('215231197',
#   'jealousy hides in pride and calls itself discernment ',
#   'Jealousy hides in pride and calls itself discernment.'),
#  ('215231197',
#   'refining my focus on things that really matter  like listening to silly requests from my kids and actually doing them  the dishes will be clean at the end of the day anyway ',
#   'Refining my focus on things that really matter. Like listening to silly requests from my kids and actually doing them. The dishes will be clean at the end of the day anyway.'),
#  ('215231197',
#   'this year  i stopped being hard on myself  i m ok with just taking the fresh laundry out of the machine and letting it sit on a chair  untouched for days ',
#   "This year, I stopped being hard on myself. I'm ok with just taking the fresh laundry out of the machine and letting it sit on a chair, untouched for days."),
#  ('215231197',
#   'if marriage is just a freaking paper  then why not sign it  afraid are you ',
#   'If marriage is just a freaking paper, then why not sign it? Afraid are you?'),
#  ('215231197',
#   'be good stewards of each other s conscience ',
#   "Be good stewards of each other's conscience."),
#  ('215231197',
#   'idolatry is spiritual adultery ',
#   'Idolatry is spiritual adultery.'),
#  ('215231197', 'rest is an inside job ', 'Rest is an inside job.'),
#  ('215231197', 'fear masquerades as wisdom ', 'Fear masquerades as wisdom.'),
#  ('215231197',
#   'i wish to see things not as they are but as they should be ',
#   'I wish to see things not as they are but as they should be.'),
#  ('215231197', 'hiding to be revealed ', 'Hiding to be revealed.'),
#  ('215231197', 'ayun  foto finish nanaman ', 'Ayun, foto finish nanaman.'),
#  ('215231197',
#   'if you want peace that transcends understanding  then stop trying to understand  wisdom requires humility ',
#   'If you want peace that transcends understanding, then stop trying to understand. Wisdom requires humility.'),
#  ('215231197',
#   'some concepts are never meant to be understood but admired ',
#   'Some concepts are never meant to be understood but admired.'),
#  ('215231197',
#   'are you on the wrong side  fighting for the right thing ',
#   'Are you on the wrong side, fighting for the right thing?'),
#  ('215231197',
#   'god  i need more patience      #homeschooling',
#   'God, I need more patience!!!!  #Homeschooling'),
#  ('215231197',
#   'religion hurts people  it was religion that hung a man on a tree ',
#   'Religion hurts people. It was religion that hung a man on a tree.'),
#  ('215231197',
#   'i give up my  right to be offended ',
#   'I give up my  right to be offended.'),
#  ('215231197',
#   'purple yum  ube chia pancake with cheeeese ',
#   'Purple yum. Ube chia pancake with cheeeese.'),
#  ('215231197',
#   'in a world full of propaganda  the truth is a conspiracy ',
#   'In a world full of propaganda, the truth is a conspiracy.'),
#  ('215231197',
#   'err on the side of adventure ',
#   'Err on the side of adventure.'),
#  ('215231197',
#   'my daughter is being very punny nowadays  i  think it s very funny ',
#   "My daughter is being very punny nowadays. I  think it's very funny."),
#  ('215231197',
#   'this generation is obsessed with itself ',
#   'This generation is obsessed with itself.'),
#  ('215231197',
#   'the answer to everything  bend the knee ',
#   'The answer to everything: Bend the knee.'),
#  ('215231197',
#   'the ability to control our thoughts is a superpower ',
#   'The ability to control our thoughts is a superpower.'),
#  ('215231197',
#   '   cancel culture is a culture of fools  with cancel culture',
#   '"""cancel-culture is a culture of fools. With cancel culture'),
#  ('215231197',
#   'my eldest just discovered riddles today  it looks like this will go on for a few months  gosh',
#   'My eldest just discovered riddles today. It looks like this will go on for a few months. gosh'),
#  ('215231197',
#   'self condemnation is immature suicide ',
#   'self-condemnation is immature suicide.'),
#  ('215231197',
#   'i am going against the grain ',
#   'I am going against the grain.'),
#  ('215231197',
#   'it is truly a sad thing to know that not everyone is able to discern the times ',
#   'It is truly a sad thing to know that not everyone is able to discern the times.'),
#  ('215231197',
#   'no to eternal life   then eternal death it is ',
#   'NO to eternal life?  Then eternal death it is.'),
#  ('215231197', 'have fun  make it last ', 'Have fun! Make it last!'),
#  ('215231197',
#   'true unity requires diversity  it does not tolerate diversity  it celebrates it ',
#   'True unity requires diversity. it does not tolerate diversity, it celebrates it.'),
#  ('215231197',
#   'don t be unified in stupidity ',
#   "don't be unified in stupidity."),
#  ('215231197',
#   'self righteousness is an oxymoron  note the word  moron  within the word ',
#   "Self-righteousness is an oxymoron. Note the word 'moron' within the word."),
#  ('215231197',
#   'the church must be the first to turn from her  wicked ways ',
#   'The church must be the first to turn from her  wicked ways.'),
#  ('215231197',
#   'that bridge that i said i would cross when i get to it  well   it now ',
#   'That bridge that I said I would cross when I get to it, well...it now.'),
#  ('215231197',
#   'i will give back what the locust have eaten ',
#   'I will give back what the locust have eaten.'),
#  ('215231197',
#   ' deadlines are sent from heaven via hell     best advice yet ',
#   "'Deadlines are sent from heaven via hell.'   best advice yet."),
#  ('215231197',
#   '   the discovery of innocence is its loss    ',
#   '"""The discovery of innocence is its loss."""'),
#  ('215231197', 'drawing a line in the sand ', 'Drawing a line in the sand.'),
#  ('215231197',
#   'the truth will either offend or encourage you  in the end  it will set you free if you let it ',
#   'The truth will either offend or encourage you. in the end, it will set you free if you let it.'),
#  ('215231197', 'turning stones to bread ', 'Turning stones to bread.'),
#  ('215231197',
#   'turning the other cheek quite often nowadays   all these storms might just mean i am doing something right ',
#   'Turning the other cheek quite often nowadays.  All these storms might just mean I am doing something right.'),
#  ('215231197',
#   'it is better to speak the truth that hurts then heals than speak falsehood that comforts then kills ',
#   'It is better to speak the truth that hurts then heals than speak falsehood that comforts then kills.'),
#  ('215231197',
#   'hell believes in your potential more than you believe in yourself  this is why they are out to keep you deceived  down  and unbelieving ',
#   'Hell believes in your potential more than you believe in yourself. This is why they are out to keep you deceived, down, and unbelieving.'),
#  ('215231197',
#   'the lies are clues to uncover the truth  the devil is a deceiver  he is not that creative at all ',
#   'The lies are clues to uncover the truth. The devil is a deceiver, he is not that creative at all.'),
#  ('215231197',
#   'wake up  you sleeper   be deceived no more  truth seeker ',
#   'Wake up, you sleeper!  Be deceived no more, truth seeker.')]
# time: 484 ms (started: 2022-05-03 10:36:07 -04:00)

# %%
# extract the hash words and keep the cleaned tweets
hash_tweet = txt_clean_tweet.map(lambda x:(x[0],extract_hash_words(x[1]),x[2]))
hash_tweet.take(5)
# Out:
# [('215231197', [], 'Stay gold, Pony Boy.'),
#  ('215231197', [], 'your tone gives you away.'),
#  ('215231197',
#   [],
#   'This unbelieving world has nowhere to rest its weary head.'),
#  ('215231197', [], 'Jealousy hides in pride and calls itself discernment.'),
#  ('215231197',
#   [],
#   'Refining my focus on things that really matter. Like listening to silly requests from my kids and actually doing them. The dishes will be clean at the end of the day anyway.')]
# time: 516 ms (started: 2022-05-03 10:36:07 -04:00)

# %%
# only keep the hash words
hash_words = hash_tweet.map(lambda x:(x[0],x[1]))
hash_words.take(5)
# Out:
# [('215231197', []),
#  ('215231197', []),
#  ('215231197', []),
#  ('215231197', []),
#  ('215231197', [])]
# time: 500 ms (started: 2022-05-03 10:36:08 -04:00)

# %%
# change the form of the hash words for LDA
## filter out the empty lists
hash_words = hash_words.filter(lambda x: x[1]!=[])
## group by userid
user_hash_words = hash_words.groupByKey().mapValues(list).collect()
user_hash_words[0:5]
# Out:
# [('257832450',
#   [['ps', 'vgfgamers', 'godofwar'],
#    ['philsprovisions'],
#    ['philsprovisions'],
#    ['flyeaglesfly'],
#    ['philsprovisions'],
#    ['philsprovisions'],
#    ['philsprovisions'],
#    ['philsprovision'],
#    ['philsprovisions'],
#    ['philsprovisions'],
#    ['roadtorecovery'],
#    ['epiccollapse', 'fantasyfootball'],
#    ['philsprovisions'],
#    ['philsprovisions']]),
#  ('2484021120',
#   [['greek', 'newyear'],
#    ['greek', 'christosstaikouras'],
#    ['life'],
#    ['saudi', 'jamalkhashoggi', 'security'],
#    ['exodus', 'lebanon', 'home', 'cyprus'],
#    ['greece', 'cave', 'kapsia'],
#    ['mars', 'perseverance', 'alien'],
#    ['omicron', 'delta', 'lab'],
#    ['invested', 'amazon'],
#    ['projecttasmania', 'mysterious', 'blackbox', 'aliens'],
#    ['sunken', 'warship', 'riverthames'],
#    ['beautiful', 'greece', 'dragon', 'cave'],
#    ['frigid', 'outdoors'],
#    ['ghislainemaxwell', 'jeffreyepstein', 'sextrafficking', 'princeandrew'],
#    ['turkey', 'secret', 'missiles', 'nuclear', 'nordicmonitor'],
#    ['nasa', 'alien', 'jameswebb', 'space', 'telescope'],
#    ['woundedknee', 'usarmy', 'sioux'],
#    ['poll', 'erdogan', 'imamoglu', 'yavas'],
#    ['turkishlira'],
#    ['reuters', 'us', 'drone', 'turkey', 'syria'],
#    ['greek', 'funeral', 'videos', 'photos'],
#    ['earthquake', 'crete', 'google', 'photos'],
#    ['nba', 'giannis', 'bucks', 'video'],
#    ['michaeljordan'],
#    ['caves', 'greece'],
#    ['stage', 'world'],
#    ['coronovirus', 'pandemic', 'attica'],
#    ['greece', 'omicron', 'quarantine'],
#    ['athens', 'ambulance', 'fire', 'video', 'photos'],
#    ['omicron', 'covid', 'uk'],
#    ['watch', 'greatwhite', 'shark', 'video'],
#    ['elonmusk', 'space', 'starlink', 'satellites', 'china'],
#    ['turkish', 'influencer', 'turkey', 'penis', 'photos'],
#    ['lightning', 'video'],
#    ['caves', 'greece'],
#    ['timecapsule', 'statue'],
#    ['lordoftherings', 'photos'],
#    ['poland', 'germany', 'eu', 'fourthreich'],
#    ['reports', 'unexplained', 'sightings', 'northernireland'],
#    ['bad', 'weather', 'greece', 'phenomena', 'west'],
#    ['windsor', 'castle', 'queen', 'christmas', 'video'],
#    ['crete', 'video'],
#    ['nasa', 'webbtelescope', 'hubble', 'universe'],
#    ['caves', 'greece', 'cave'],
#    ['ancientgreek', 'christmas'],
#    ['japanese', 'pilot', 'pearlharbor', 'us'],
#    ['traditional', 'greek', 'christmas', 'video'],
#    ['mysterious', 'venezuela', 'video'],
#    ['desmondtutu', 'nobel'],
#    ['greek', 'president'],
#    ['turkey', 'church', 'mosque', 'christmaseve'],
#    ['greeks', 'christmastree'],
#    ['christmas', 'carols', 'greece', 'videos'],
#    ['greek', 'church', 'christians', 'mossialos'],
#    ['coronavirus', 'greece'],
#    ['nasa', 'jupiter'],
#    ['euroleague', 'basketball'],
#    ['ecumenical', 'bartholomew', 'covid'],
#    ['stefanos', 'tsitsipas'],
#    ['maria', 'sakkari'],
#    ['refugees'],
#    ['temple', 'hercules', 'spain', 'video'],
#    ['wsj', 'us', 'europe', 'greece', 'american', 'military', 'economy'],
#    ['netherlands', 'lockdown', 'crisis'],
#    ['shops', 'supermarkets', 'holiday'],
#    ['googleearth', 'us', 'stealth', 'missouri', 'photo'],
#    ['christmas', 'wreaths'],
#    ['airlines', 'holiday', 'omicron'],
#    ['turkish', 'media', 'tsipras', 'syriza'],
#    ['caves', 'greece'],
#    ['vce', 'greek', 'melbourne'],
#    ['ostraca', 'greek', 'demotic', 'egypt'],
#    ['turkey', 'greek'],
#    ['coronavirus', 'greece'],
#    ['isis', 'athens'],
#    ['christmas', 'spotify'],
#    ['greek', 'panagiotopoulos'],
#    ['greek', 'army'],
#    ['omicronvariant'],
#    ['giannis', 'antetokounmpo', 'sakkari', 'greek'],
#    ['turkish', 'greek'],
#    ['putin', 'turkey'],
#    ['iiss', 'france', 'greece', 'mediterranean', 'analysis'],
#    ['shock', 'turkey', 'video'],
#    ['sex', 'boys', 'orphanage'],
#    ['us', 'turkey', 'drone', 'ethiopia'],
#    ['ring', 'shipwrecks', 'israel', 'video'],
#    ['egypt', 'cyprus', 'turkey'],
#    ['greece', 'cave'],
#    ['elonmusk', 'cnn'],
#    ['turkey', 'greek'],
#    ['breakingnews', 'covid'],
#    ['greek', 'cheese', 'cnn'],
#    ['coronavirus', 'greece'],
#    ['greek', 'radioarvyla'],
#    ['covidvaccine'],
#    ['omicronvariant', 'delta'],
#    ['palm'],
#    ['greek', 'christmas', 'covid']]),
#  ('587315250', [['bendthecurve'], ['tutu'], ['dontlookup', 'maga']]),
#  ('1200590162',
#   [['samesexmarriage'],
#    ['niravmodi'],
#    ['newprofilepic'],
#    ['congress', 'congressmuktbharat'],
#    ['republicday',
#     'farmersprostests',
#     'newdelhi',
#     'pmoindia',
#     'modi',
#     'modiwithfarmers'],
#    ['rubinaistheboss', 'biggboss']]),
#  ('112758020',
#   [['chickenlicken'],
#    ['stressed', 'unisa', 'studentlife'],
#    ['sapskzn'],
#    ['betway'],
#    ['theundergroundrailroad']])]
# time: 5.44 s (started: 2022-05-03 10:36:08 -04:00)

# %%
len(user_hash_words)
# Out:
# 511
# time: 0 ns (started: 2022-05-03 10:36:14 -04:00)

# %% [markdown]
# ## Self-define LDA for Hash Words

# %%
import logging
import numpy as np
import random


class user_tweet:
    def __init__(self,tweets,word2id):
        self.t_words = [words(tweet,word2id) for tweet in tweets]
        self.size = len(tweets)

class user:
    def __init__(self,tmp):
        self.id = [user[0] for user in tmp]
        
        self.size = len(self.id)
        self.word2id = {}
        self.words = []
        self.wordsize = 0
        ind = 0
        for i in range(len(tmp)):
            for j in range(len(tmp[i][1])):
                for k in range(len(tmp[i][1][j])):
                    if tmp[i][1][j][k] in self.word2id:
                        self.words.append(self.word2id[tmp[i][1][j][k]])
                    else:
                        self.word2id[tmp[i][1][j][k]] = ind
                        self.words.append(ind)
                        ind += 1
        self.wordsize = len(self.words)
        self.tweets = dict({zzz[0]:user_tweet(zzz[1],self.word2id) for zzz in tmp})

class words:
    def __init__(self,tweet,word2id):
        self.words = []
        self.size = 0
        self.word2id = word2id
        for i in range(len(tweet)):
            self.words.append(self.word2id[tweet[i]])
        self.size = len(self.words)


class twitter_lda:
    def __init__(self,K,iter,alpha,beta,beta_b,gamma,data,top_max_num):
        self.K = K
        self.users = user(data)
        self.user_count = self.users.size
        self.word_count = self.users.wordsize
        self.iter = iter

        self.top_max_num = top_max_num

        self.alpha_g = alpha
        self.beta = beta
        self.beta_b = np.array([beta_b for i in range(self.word_count)])
        self.beta_b_sum = beta_b * self.word_count
        self.beta_word = np.array([beta for i in range(self.word_count)])
        self.beta_word_sum = beta * self.word_count
        self.gamma = np.array([gamma,gamma])

        self.alpha_sum = 0
        self.alpha_general = np.array([self.alpha_g for i in range(self.K)])
        self.alpha_sum = self.alpha_g*self.K

        self.c_ua = np.array([[0 for i in range(self.K)] for i in range(self.user_count)])
        self.theta_general = np.array([[0.0 for i in range(self.K)] for i in range(self.user_count)])

        self.c_lv=np.array([0,0])

        self.rho = np.array([0,0])

        #self.c_word = [[0 for i in range(self.word_count)] for i in range(self.K)]
        self.c_word = np.zeros((self.K,self.word_count))
        #self.phi_word = [[0.0 for i in range(self.word_count)] for i in range(self.K)]
        self.phi_word = np.zeros((self.K,self.word_count))
        
        self.c_b = np.array([0 for i in range(self.word_count)])
        self.phi_background = np.array([0.0 for i in range(self.word_count)])

        self.countAllWord = np.array([0 for i in range(self.K)])

    def ini(self):
        u = 0
        d = 0
        w = 0

        self.z = [[] for id in self.users.id]
        self.x = [[] for id in self.users.id]

        for u in range(self.users.size):
            id = self.users.id[u]
            self.z[u] = [0 for i in range(self.users.tweets[id].size)]
            self.x[u] = [[] for i in range(self.users.tweets[id].size)]
            #print(u)
            for d in range(self.users.tweets[id].size):
                twitter_word = self.users.tweets[id].t_words[d]
                self.x[u][d] = [False for i in range(twitter_word.size)]

                a_general = random.randint(0,self.K-1)

                self.z[u][d] = a_general
                self.c_ua[u][a_general] += 1

                for w in range(twitter_word.size):
                    word = twitter_word.words[w]
                    randback = random.randint(0,1)
                    if randback == 0:
                        self.c_lv[1] += 1
                        self.c_word[a_general][word] += 1
                        self.countAllWord[a_general] += 1
                        self.x[u][d][w] = True
                    else:
                        self.c_lv[0] += 1
                        self.c_b[word] += 1
                        self.x[u][d][w] = False

    def est(self):
        for i in range(self.iter):
            print("iteration: " + str(i))
            self.sweep()
        self.update_distribution()



    def sweep(self):
        for cntuser in range(self.users.size):
            id = self.users.id[cntuser]
            for cnttweet in range(self.users.tweets[id].size):
                twitter_word = self.users.tweets[id].t_words[cnttweet]
                self.sample_z(cntuser,cnttweet,id,twitter_word)
                for cntword in range(twitter_word.size):
                    word = twitter_word.words[cntword]
                    self.sample_x(cntuser,cnttweet,cntword,word)

    def update_distribution(self):

        for u in range(self.user_count):
            c_u_a = 0
            #for a in range(self.K):
                #c_u_a += self.c_ua[u][a]
            c_u_a = self.c_ua[u].sum()
            #for a in range(self.K):
                #self.theta_general[u][a] = (self.c_ua[u][a] + self.alpha_general[a])/(c_u_a + self.alpha_sum)
            self.theta_general[u] = (self.c_ua[u] + self.alpha_general[0])/(c_u_a + self.alpha_sum)
            for a in range(self.K):
                c_v = self.c_word[a].sum()
                #for v in range(self.word_count):
                 #   c_v += self.c_word[a][v]

                self.phi_word = (self.c_word + self.beta_word[0]) / (c_v + self.beta_word_sum)
            
            c_b_v = self.c_b.sum()
            #for v in range(self.word_count):
             #   c_b_v += self.c_b[v]
            
            self.phi_background = (self.c_b + self.beta_b[0]) / (c_b_v + self.beta_b_sum)
            #for v in range(self.word_count):
                #self.phi_background[v] = (self.c_b[v] + self.beta_b[v]) / (c_b_v + self.beta_b_sum)

            for l in range(2):
                self.rho[0] = (self.c_lv[0] + self.gamma[0]) / (self.c_lv[0] + self.c_lv[1] + self.gamma[0] + self.gamma[1])
                self.rho[1] = (self.c_lv[1] + self.gamma[1]) / (self.c_lv[0] + self.c_lv[1] + self.gamma[0] + self.gamma[1])

            print("finish:"+str(u)+"/"+str(self.user_count))




    def sample_x(self,u,d,n,word):
        binarylabel = self.x[u][d][n]
        binary = 0
        if binarylabel:
            binary = 1
        else:
            binary = 0
        self.c_lv[binary] -= 1
        if binary == 0:
            self.c_b[word] -= 1
        else:
            self.c_word[self.z[u][d]][word] -= 1
            self.countAllWord[self.z[u][d]] -= 1

        binarylabel = self.draw_x(u,d,n,word)

        self.x[u][d][n] = binarylabel

        if binarylabel:
            binary = 1
        else:
            binary = 0

        self.c_lv[binary] += 1

        if binary == 0:
            self.c_b[word] += 1
        else:
            self.c_word[self.z[u][d]][word] += 1
            self.countAllWord[self.z[u][d]] += 1


    def draw_x(self,u,d,n,word):
        p_lv = [0.0,0.0]
        pb = 1
        ptopic = 1
        p_lv[0] = (self.c_lv[0] + self.gamma[0])/(self.c_lv[0] + self.c_lv[1] + self.gamma[0] + self.gamma[1])
        p_lv[1] = (self.c_lv[1] + self.gamma[1]) / (self.c_lv[0] + self.c_lv[1] + self.gamma[0] + self.gamma[1])

        pb = (self.c_b[word] + self.beta_b[word])/(self.c_lv[0]+self.beta_b_sum)
        ptopic = (self.c_word[self.z[u][d]][word] + self.beta_word[word])/(self.countAllWord[self.z[u][d]] + self.beta_word_sum)

        p0 = pb * p_lv[0]
        p1 = pb * p_lv[1]

        sum = p0 + p1
        randpick = random.random()
        if randpick <= p0/sum:
            return False
        else:
            return True

    def sample_z(self,u,d,buffer_user,tw):
        tweet_topic = self.z[u][d]
        #w = 0
        self.c_ua[u][tweet_topic] -= 1
        for w in range(tw.size):
            word = tw.words[w]
            if self.x[u][d][w] == True:
                self.c_word[tweet_topic][word] -= 1
                self.countAllWord[tweet_topic] -= 1

        tweet_topic = self.draw_z(u,d,buffer_user,tw)

        self.z[u][d] = tweet_topic

        self.c_ua[u][tweet_topic] += 1
        for w in range(tw.size):
            word = tw.words[w]
            if self.x[u][d][w] == True:
                self.c_word[tweet_topic][word] += 1
                self.countAllWord[tweet_topic] += 1


    def draw_z(self,u,d,buffer_user,tw):

        p_topic = [0.0 for i in range(self.K)]
        self.pcount = [0 for i in range(self.K)]

        wordcnt = {}
        totalwords = 0

        for w in range(tw.size):
            if self.x[u][d][w]:
                totalwords += 1
                word = tw.words[w]
                if word not in wordcnt:
                    wordcnt[word] = 1
                else:
                    wordcnt[word] += 1

        for a in range(self.K):
            p_topic[a] = (self.c_ua[u][a] + self.alpha_general[a]) / (self.users.tweets[buffer_user].size - 1 + self.alpha_sum)
            buffer_p = 1
            i = 0
            for word,buffer_cnt in wordcnt.items():
                for j in range(buffer_cnt):
                    value = (self.c_word[a][word] + self.beta_word[word] + j) / (self.countAllWord[a] + self.beta_word_sum + i)
                    i += 1
                    buffer_p *= value
                    buffer_p = self.isoverflow(buffer_p,a)

            p_topic[a] *= pow(buffer_p,1.0)

        p_topic = self.recompute(p_topic,self.pcount)

        randz = random.random()

        sum = 0

        for a in range(self.K):
            sum += p_topic[a]

        thred = 0.0
        chosena = -1

        for a in range(self.K):
            thred += p_topic[a] / sum
            if thred >= randz:
                chosena = a
                break

        return chosena


    def recompute(self,p_topic,pcount):
        max = pcount[0]

        for i in range(1,len(pcount)):
            if pcount[i] > max:
                max = pcount[i]

        for i in range(len(pcount)):
            p_topic[i] = p_topic[i] * pow(1e150,pcount[i]-max)

        return p_topic

    def isoverflow(self,buffer_p,a2):
        if buffer_p>1e150:
            self.pcount[a2] += 1
            return buffer_p/1e150
        if buffer_p<1e-150:
            self.pcount[a2] -= 1
            return buffer_p * 1e150
        return buffer_p

    def getTop(self,phi):
        ind = 0
        rank = []
        tmp = []
        num = min(self.top_max_num,len(phi))
        for i in range(num):
            max = -100000
            for j in range(len(phi)):
                if j in tmp:
                    continue
                if phi[j] >max:
                    ind = j
                    max = phi[j]
            rank.append([ind,max])
            tmp.append(ind)
        return rank


    def outputWordsInTopics(self):

        topic_word = []
        va = dict({value:key for key,value in self.users.word2id.items()})
        for a in range(self.K):
            tmp = self.getTop(self.phi_word[a])
            topic_word.append([])
            for i in range(len(tmp)):
                topic_word[a].append([va[tmp[i][0]],tmp[i][1]])

        return topic_word
# Out:
# time: 0 ns (started: 2022-05-03 10:36:14 -04:00)

# %%
def outputWordsInTopics(phi_word, word2id, num_topic, num_top_words): ##################### add num_topic and num_top_words

        topic_word = []
        va = dict({value:key for key,value in word2id.items()})
        for a in range(num_topic):
            tmp = getTop(phi_word[a], num_top_words) ############################### add num_top_words
            topic_word.append([])
            for i in range(len(tmp)):
                #print(tmp[i])
                topic_word[a].append([va[tmp[i][0]],tmp[i][1]])

        return topic_word
    

def getTop(phi, num_top_words):############################### add num_top_words
    ind = 0
    rank = []
    tmp = []
    #num = min(self.top_max_num,len(phi))
    for i in range(num_top_words): ########################### I CHANGED 30 TO num_top_words##################
        max = -100000
        for j in range(len(phi)):
            if j in tmp:
                continue
            if phi[j] >max:
                ind = j
                max = phi[j]
        rank.append([ind,max])
        tmp.append(ind)
    return rank
# Out:
# time: 16 ms (started: 2022-05-03 10:36:14 -04:00)

# %%
# conduct LDA
num_topic = 30
num_iteration = 20
lda = twitter_lda(num_topic,num_iteration,0.01,0.01,0.01,0.01,user_hash_words,50)
# Out:
# time: 31 ms (started: 2022-05-03 10:36:14 -04:00)

# %%
lda.users.wordsize
# Out:
# 20206
# time: 0 ns (started: 2022-05-03 10:36:14 -04:00)

# %%
lda.ini()
# Out:
# time: 94 ms (started: 2022-05-03 10:36:14 -04:00)

# %%
lda.est()
# Out:
# iteration: 0
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4
# iteration: 5
# iteration: 6
# iteration: 7
# iteration: 8
# iteration: 9
# iteration: 10
# iteration: 11
# iteration: 12
# iteration: 13
# iteration: 14
# iteration: 15
# iteration: 16
# iteration: 17
# iteration: 18
# iteration: 19
# finish:0/511
# finish:1/511
# finish:2/511
# finish:3/511
# finish:4/511
# finish:5/511
# finish:6/511
# finish:7/511
# finish:8/511
# finish:9/511
# finish:10/511
# finish:11/511
# finish:12/511
# finish:13/511
# finish:14/511
# finish:15/511
# finish:16/511
# finish:17/511
# finish:18/511
# finish:19/511
# finish:20/511
# finish:21/511
# finish:22/511
# finish:23/511
#   ['sydney', 0.0019090462329414434],
#   ['amanecer', 0.0019090462329414434],
#   ['sunrise', 0.0019090462329414434],
#   ['sunset', 0.0019090462329414434],
#   ['sunrisephotography', 0.0019090462329414434],
#   ['sunsetphotography', 0.0019090462329414434],
#   ['reinota', 0.0019090462329414434],
#   ['legend', 0.0019090462329414434],
#   ['chelsea', 0.0019090462329414434],
#   ['chebha', 0.0019090462329414434],
#   ['bbl', 0.0019090462329414434],
#   ['cricket', 0.0019090462329414434],
#   ['crickettwitter', 0.0019090462329414434],
#   ['libertybowl', 0.0019090462329414434],
#   ['nfltwitter', 0.0019090462329414434]]]
# time: 12.8 s (started: 2022-05-03 10:37:40 -04:00)

# %%
num_top_words = 15
topic_words = outputWordsInTopics(lda.phi_word,lda.users.word2id,num_topic,num_top_words)
topic_words_array = np.array(topic_words)[:,:,0]
topic_words_array
# Out:
# array([['mdundovibes', 'ghanamusic', 'mdundonews', 'happybirthday',
#         'dontcryprguy', 'killthebill', 'ghanaartiste', 'mdundogh',
#         'newmusicghana', 'listenonmdundo', 'mondaymotivation', 'ghmusic',
#         'tupperware', 'holdtheline', 'newyear'],
#        ['yahoo', 'nfl', 'jesussaves', 'lifestyle', 'mothersday',
#         'altmillars', 'veracruz', 'jags', 'jax', 'covid', 'smartnews',
#         'moderndeluxeseries', 'gopackgo', 'miraclesacross', 'nofearhere'],
#        ['poshmark', 'shopmycloset', 'style', 'gmixmag', 'fashion',
#         'marketing', 'businesstransformation', 'leadership',
#         'changemanagement', 'leadershiptips', 'employeeexperience',
#         'bitcoin', 'uhc', 'ghfutures', 'sustainability'],
#        ['flyeaglesfly', 'eagles', 'nfl', 'nfltwitter', 'gobirds', 'jets',
#         'takeflight', 'phi', 'phivsnyj', 'giants', 'nygvsphi',
#         'goldcoast', 'iubb', 'kalundetalks', 'washingtonfootball'],
#        ['dontspyonus', 'cleanupthessa', 'callofdutymodernwarfare',
#         'research', 'spain', 'rica', 'austax', 'ps', 'kerajaangagal',
#         'malaysia', 'ssareform', 'spanishfood', 'thailand', 'lawan',
#         'nbktoday'],
#        ['sccl', 'sclife', 'prolife', 'cashbox', 'death', 'abortion',
#         'life', 'top', 'midlandsgives', 'nrlc', 'supportsupporters',
#         'december', 'abortionondemand', 'dmv', 'prc'],
#        ['holidayherethisyear', 'seeaustralia', 'followsuit', 'feelnsw',
#         'thisiswa', 'thisisqueensland', 'australiasnorthwest',
#         'ilovesydney', 'chiefskingdom', 'dodgers', 'dmxforever',
#         'supportlarb', 'kodakblack', 'dmx', 'dmxrip'],
#        ['dartmouth', 'inbusinessforabetterworld', 'q', 'law',
#         'newprofilepic', 'kuwait', 'criminalcourt', 'independenceday',
#         'cybercrimes', 'jailsentence', 'southwestlondon', 'climate',
#         'ricardoanaya', 'divorce', 'migrantworkers'],
#        ['biggbosstamil', 'biggboss', 'sweepstakes', 'priyanka', 'ccp',
#         'amir', 'venmome', 'pavni', 'thamarai', 'raju', 'taiwan',
#         'keytowyn', 'abinay', 'buschtothemoon', 'allstarrace'],
#        ['nigeria', 'israel', 'empathy', 'lng', 'evidence', 'hydrogen',
#         'equality', 'empowerment', 'visayas', 'gas', 'amihan',
#         'metraweather', 'rains', 'rblfcb', 'ironore'],
#        ['aidspan', 'gfo', 'ofm', 'via', 'agourahills', 'persianfood',
#         'persianrestaurant', 'maralcuisine', 'authenticpersianfood',
#         'persiancuisine', 'losangelesfood', 'californiarestaurants',
#         'covid', 'flower', 'natural'],
#        ['thespirituallibrary', 'lartdexplicarlart',
#         'internationaldayofthegirl', 'valentinesday_misleadingyouth',
#         'pwdquiz', 'mppd_androidapp', 'ps', 'equalforbetter',
#         'plangirlstakeover', 'backinggreen', 'downingstreetparty',
#         'flyeaglesfly', 'covid', 'heretheycome', 'fuckdallas'],
#        ['greek', 'letsgobrandonreallymeans', 'greece', 'indieauthor',
#         'linux', 'covid', 'joerogan', 'eternals', 'apple',
#         'philsprovisions', 'cave', 'turkey', 'spidermannowayhome',
#         'spiderman', 'nowayhome'],
#        ['science_in_sanskrit', 'indvnz', 'nzvban', 'cricketnation',
#         'nowplaying', 'raptors', 'onthisday', 'twitter', 'sanskrit',
#         'ps', 'newprofilepic', 'cricket', 'fordtrophy', 'italy',
#         'oxidize'],
#        ['inkhabar', 'omicron', 'newyear', 'coronavirus',
#         'omicronvariant', 'happynewyear', 'teamindia', 'delhi',
#         'bollywoodupdates', 'thunderup', 'andjustlikethat', 'covid',
#         'newprofilepic', 'pmmodi', 'indiaupdate'],
#        ['ygk', 'ethiopia', 'tcmparty', 'au', 'holidayplaylist', 'kenya',
#         'southsudan', 'somalia', 'rhoc', 'projectrunway', 'teachers',
#         'ukieri', 'djibouti', 'gototurkey', 'visitrwanda'],
#        ['burundi', 'ukbusiness', 'springst', 'ecig', 'gasfreevic',
#         'hawaii', 'seo', 'nails', 'nailtechnician', 'auspol',
#         'offshorewind', 'vicclimatesolutions', 'furniture', 'carehire',
#         'carelease'],
#        ['thestig', 'india', 'china', 'russia', 'afghanistan', 'usa',
#         'digital', 'indopacific', 'biden', 'expo', 'myanmar', 'pakistan',
#         'dubaiairshow', 'sanctions', 'tech'],
#        ['thenews', 'tns', 'covid', 'golfinuae', 'abudhabigp',
#         'allindiainfluencersmeet', 'incredibleindia', 'christmas', 'uae',
#         'f', 'gujarat', 'insecure', 'mumbai', 'indiavssouthafrica',
#         'viratkohli'],
#        ['lgbtq', 'lgbt', 'lgbtiq', 'humanrights', 'gay', 'transgender',
#         'chile', 'srilanka', 'us', 'tamil', 'covid', 'india', 'russia',
#         'lsbti', 'lsbtiq'],
#        ['vimeo', 'whatshappeninginmyanmar', 'junta', 'mar', 'myanmar',
#         'juntapolicebrutality', 'juntaarmybrutality', 'yangon',
#         'againstmyanmarmilitarycoup', 'juntacrimes',
#         'crimesagainsthumanity', 'mandalay', 'springrevolutionmyanmar',
#         'juntaterrorists', 'arangkadaforum'],
#        ['startupindia', 'startupstory', 'startups', 'startup',
#         'enterpreneurs', 'entrepreneurship', 'business', 'businessstory',
#         'startupstories', 'australia', 'vegan', 'southwestlondon',
#         'israel', 'newyears', 'sydney'],
#        ['hepsat', 'sunburngoa', 'eagles', 'cashflow', 'africa',
#         'aviation', 'staysafe', 'lifeiscalling', 'liveinyourlivingroom',
#         'jeno', 'vimeo', 'resisttheresistance', 'nct',
#         'shorttermrentals', 'expediteneetpgcounselling'],
#        ['ibs', 'ibsat', 'mba', 'mbacampus', 'bestcollege',
#         'bestbschools', 'internship', 'career', 'icfai', 'admissions',
#         'study', 'growth', 'nationalmocktest', 'pgpm', 'ibsapp'],
#        ['kengenagm', 'football', 'energychampion', 'le', 'kengen',
#         'collegefootball', 'sustainablekengen', 'sports', 'syracuse',
#         'nbatopshotthis', 'energycsinolkaria', 'bowlseason', 'goblue',
#         'ynwa', 'rolltide'],
#        ['travel', 'ozmusic', 'australasia', 'aussie', 'happynewyear',
#         'ozbands', 'aussiemusic', 'australasianmusic', 'chanyeol',
#         'baekhyun', 'oz', 'australianmusic', 'covid', 'eis', 'traveller'],
#        ['beeronthecarpet', 'beerwithaview', 'dailybrew', 'mokapot',
#         'chiefskingdom', 'impeachtrumpnow', 'commerce', 'removetrumpnow',
#         'communbr', 'vocation', 'vocationbrewery', 'swadeshgwalior',
#         'aewdynamite', 'countyweek', 'harviestounbrewery'],
#        ['playstore', 'france', 'french', 'greece',
#         'islamicheritagemonth', 'australia', 'germany', 'cyprus', 'uk',
#         'ahmadiyya', 'islam', 'revivingtrueislam', 'freedom', 'job',
#         'kahluaespressomartini'],
#        ['bahrain', 'covid', 'tf', 'weatherbahrain', 'meteorology',
#         'ccot', 'omicron', 'weather', 'coronavirus', 'wtf',
#         'badcustomerservice', 'bahrain_weather', 'fantasyfootball',
#         'dontlookup', 'cop'],
#        ['calibri', 'microsoft', 'healthtips', 'doctorshospital',
#         'bestpic', 'happydiwali', 'gettysport', 'pictureoftheday',
#         'saltillo', 'deepavali', 'deepawali', 'covid',
#         'sportsphotography', 'diwali', 'abolishdeathpenalty']],
#       dtype='<U29')
# time: 2.24 s (started: 2022-05-03 10:37:52 -04:00)

# %%
np.shape(topic_words_array)
# Out:
# (30, 15)
# time: 0 ns (started: 2022-05-03 10:37:55 -04:00)

# %%
# preset column name
column_name = []
for i in range(num_topic):
    column_name.append('Topic'+str(i))
    
topic_words_pd = pd.DataFrame(topic_words_array.T, columns = column_name)
topic_words_pd
# Out:
#               Topic0              Topic1                  Topic2  \
# 0        mdundovibes               yahoo                poshmark
# 1         ghanamusic                 nfl            shopmycloset
# 2         mdundonews          jesussaves                   style
# 3      happybirthday           lifestyle                 gmixmag
# 4       dontcryprguy          mothersday                 fashion
# 5        killthebill          altmillars               marketing
# 6       ghanaartiste            veracruz  businesstransformation
# 7           mdundogh                jags              leadership
# 8      newmusicghana                 jax        changemanagement
# 9     listenonmdundo               covid          leadershiptips
# 10  mondaymotivation           smartnews      employeeexperience
# 11           ghmusic  moderndeluxeseries                 bitcoin
# 12        tupperware            gopackgo                     uhc
# 13       holdtheline      miraclesacross               ghfutures
# 14           newyear          nofearhere          sustainability
#
#                 Topic3                   Topic4             Topic5  \
# 0         flyeaglesfly              dontspyonus               sccl
# 1               eagles            cleanupthessa             sclife
# 2                  nfl  callofdutymodernwarfare            prolife
# 3           nfltwitter                 research            cashbox
# 4              gobirds                    spain              death
# 5                 jets                     rica           abortion
# 6           takeflight                   austax               life
# 7                  phi                       ps                top
# 8             phivsnyj            kerajaangagal      midlandsgives
# 9               giants                 malaysia               nrlc
# 10            nygvsphi                ssareform  supportsupporters
# 11           goldcoast              spanishfood           december
# 12                iubb                 thailand   abortionondemand
# 13        kalundetalks                    lawan                dmv
# 14  washingtonfootball                 nbktoday                prc
#
#                  Topic6                     Topic7          Topic8  \
# 0   holidayherethisyear                  dartmouth   biggbosstamil
# 1          seeaustralia  inbusinessforabetterworld        biggboss
# 2            followsuit                          q     sweepstakes
# 3               feelnsw                        law        priyanka
# 4              thisiswa              newprofilepic             ccp
# 5      thisisqueensland                     kuwait            amir
# 6   australiasnorthwest              criminalcourt         venmome
# 7           ilovesydney            independenceday           pavni
# 8         chiefskingdom                cybercrimes        thamarai
# 9               dodgers               jailsentence            raju
# 10           dmxforever            southwestlondon          taiwan
# 11          supportlarb                    climate        keytowyn
# 12           kodakblack               ricardoanaya          abinay
# 13                  dmx                    divorce  buschtothemoon
# 14               dmxrip             migrantworkers     allstarrace
#
#           Topic9  ...                     Topic20           Topic21  \
# 0        nigeria  ...                       vimeo      startupindia
# 1         israel  ...     whatshappeninginmyanmar      startupstory
# 2        empathy  ...                       junta          startups
# 3            lng  ...                         mar           startup
# 4       evidence  ...                     myanmar     enterpreneurs
# 5       hydrogen  ...        juntapolicebrutality  entrepreneurship
# 6       equality  ...          juntaarmybrutality          business
# 7    empowerment  ...                      yangon     businessstory
# 8        visayas  ...  againstmyanmarmilitarycoup    startupstories
# 9            gas  ...                 juntacrimes         australia
# 10        amihan  ...       crimesagainsthumanity             vegan
# 11  metraweather  ...                    mandalay   southwestlondon
# 12         rains  ...     springrevolutionmyanmar            israel
# 13        rblfcb  ...             juntaterrorists          newyears
# 14       ironore  ...              arangkadaforum            sydney
#
#                       Topic22           Topic23            Topic24  \
# 0                      hepsat               ibs          kengenagm
# 1                  sunburngoa             ibsat           football
# 2                      eagles               mba     energychampion
# 3                    cashflow         mbacampus                 le
# 4                      africa       bestcollege             kengen
# 5                    aviation      bestbschools    collegefootball
# 6                    staysafe        internship  sustainablekengen
# 7               lifeiscalling            career             sports
# 8        liveinyourlivingroom             icfai           syracuse
# 9                        jeno        admissions     nbatopshotthis
# 10                      vimeo             study  energycsinolkaria
# 11        resisttheresistance            growth         bowlseason
# 12                        nct  nationalmocktest             goblue
# 13           shorttermrentals              pgpm               ynwa
# 14  expediteneetpgcounselling            ibsapp           rolltide
#
#               Topic25             Topic26                Topic27  \
# 0              travel     beeronthecarpet              playstore
# 1             ozmusic       beerwithaview                 france
# 2         australasia           dailybrew                 french
# 3              aussie             mokapot                 greece
# 4        happynewyear       chiefskingdom   islamicheritagemonth
# 5             ozbands     impeachtrumpnow              australia
# 6         aussiemusic            commerce                germany
# 7   australasianmusic      removetrumpnow                 cyprus
# 8            chanyeol            communbr                     uk
# 9            baekhyun            vocation              ahmadiyya
# 10                 oz     vocationbrewery                  islam
# 11    australianmusic      swadeshgwalior      revivingtrueislam
# 12              covid         aewdynamite                freedom
# 13                eis          countyweek                    job
# 14          traveller  harviestounbrewery  kahluaespressomartini
#
#                Topic28              Topic29
# 0              bahrain              calibri
# 1                covid            microsoft
# 2                   tf           healthtips
# 3       weatherbahrain      doctorshospital
# 4          meteorology              bestpic
# 5                 ccot          happydiwali
# 6              omicron           gettysport
# 7              weather      pictureoftheday
# 8          coronavirus             saltillo
# 9                  wtf            deepavali
# 10  badcustomerservice            deepawali
# 11     bahrain_weather                covid
# 12     fantasyfootball    sportsphotography
# 13          dontlookup               diwali
# 14                 cop  abolishdeathpenalty
#
# [15 rows x 30 columns]
# time: 32 ms (started: 2022-05-03 10:37:55 -04:00)

# %%
topic_words_pd.to_csv('./result_topic_words.csv', index=True, header=True)
# Out:
# time: 31 ms (started: 2022-05-05 16:51:25 -04:00)

# %% [markdown]
# ## Extract More Words for Each Topic

# %%
def find_pos(word):
    # Part of Speech constants
    # ADJ, ADJ_SAT, ADV, NOUN, VERB = 'a', 's', 'r', 'n', 'v'

    pos = nltk.pos_tag(nltk.word_tokenize(word))[0][1]
    
    # Adjective tags - 'JJ', 'JJR', 'JJS'
    if pos.lower()[0] == 'j':
        return 'a'
    # Adverb tags - 'RB', 'RBR', 'RBS'
    elif pos.lower()[0] == 'r':
        return 'r'
    # Verb tags - 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'
    elif pos.lower()[0] == 'v':
        return 'v'

    # Noun tags - 'NN', 'NNS', 'NNP', 'NNPS'
    else:
        return 'n'


def advanced_clean(txt):
        
    # remove url
    txt_nourl = re.sub("http\S+","",str(txt))
    
    # remove at
    txt_noat =  re.sub("@\S+","",txt_nourl)
    
    # remove punctuations and numbers
    txt_clean = re.sub('[^_a-zA-Z]',' ',txt_noat)
        
    # lowercase
    txt_lower = txt_clean.lower()
    
    # tokenize
    token = txt_lower.split()
    
    # check whether it is an English word
    english_words = []
    nltk_words = set(nltk.corpus.words.words())
    for word in token:
        if word in nltk_words and len(word)>2:
            english_words.append(word)
            
    # remove stopwords
    from nltk.corpus import stopwords
    lang_stopwords = stopwords.words('english')
    stopwords_removed = [w for w in english_words if w not in lang_stopwords]

    # lemmatize
    lemma_words = []
    wl = WordNetLemmatizer()
    for word in stopwords_removed:
        pos = find_pos(word)
        lemma_words.append(wl.lemmatize(word, pos))
    
    return lemma_words
# Out:
# time: 0 ns (started: 2022-05-03 10:37:55 -04:00)

# %%
# clean the tweets in an advanced way
hash_tweet_words = hash_tweet.map(lambda x: (x[0], x[1], advanced_clean(x[2])))
hash_tweet_words.take(5)
# Out:
# [('215231197', [], ['stay', 'gold', 'pony', 'boy']),
#  ('215231197', [], ['tone', 'away']),
#  ('215231197',
#   [],
#   ['unbelieving', 'world', 'nowhere', 'rest', 'weary', 'head']),
#  ('215231197', [], ['jealousy', 'pride', 'discernment']),
#  ('215231197',
#   [],
#   ['refining',
#    'focus',
#    'really',
#    'matter',
#    'like',
#    'listen',
#    'silly',
#    'actually',
#    'clean',
#    'end',
#    'day',
#    'anyway'])]
# time: 3.17 s (started: 2022-05-03 10:37:55 -04:00)

# %%
# remove empty hash_word list 
hash_tweet_words_noempty = hash_tweet_words.filter(lambda x: x[1]!=[] and x[2]!=[])
hash_tweet_words_noempty.take(5)
# Out:
# [('215231197', ['homeschooling'], ['god', 'need', 'patience']),
#  ('215231197', ['munchies'], ['rocky', 'road', 'whisky']),
#  ('198158303', ['bhooma_labs'], ['clock', 'link']),
#  ('198158303',
#   ['samskritam'],
#   ['please',
#    'join',
#    'listen',
#    'special',
#    'lecture',
#    'series',
#    'scientific',
#    'heritage',
#    'part',
#    'night',
#    'club',
#    'house',
#    'room']),
#  ('198158303',
#   ['hosadiganta', 'chemistry'],
#   ['ancient', 'work', 'alchemy', 'chemistry', 'chemistry'])]
# time: 12.4 s (started: 2022-05-03 10:37:58 -04:00)

# %%
# temp = hash_tweet_words_noempty.map(lambda x: x[1]).collect()
# print(temp)
# Out:
# time: 0 ns (started: 2022-05-03 10:38:10 -04:00)

# %%
# change the form of hash_tweet 
hash_tweet_words_flat = hash_tweet_words_noempty.flatMap(lambda x: [(i, x[2]) for i in x[1]]).reduceByKey(lambda x, y: x+y).cache()
hash_tweet_words_flat.take(10)
# Out:
# [('bhooma_labs', ['clock', 'link']),
#  ('religion',
#   ['word',
#    'religion',
#    'represent',
#    'dharma',
#    'read',
#    'article',
#    'love',
#    'religion',
#    'sure',
#    'must',
#    'read',
#    'essay',
#    'matter',
#    'please',
#    'read',
#    'comment',
#    'circulate',
#    'activist',
#    'inclusion',
#    'south',
#    'constitution',
#    'consider',
#    'progressive',
#    'manifest',
#    'religion',
#    'ministry',
#    'gay',
#    'bisexual',
#    'two',
#    'different',
#    'find',
#    'common',
#    'ground',
#    'monk',
#    'pastor',
#    'share',
#    'belief',
#    'organize',
#    'religion',
#    'coexist',
#    'even',
#    'society',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'freedom',
#    'take',
#    'high',
#    'virtue',
#    'mankind',
#    'ability',
#    'want',
#    'want',
#    'give',
#    'discard',
#    'old',
#    'fashion',
#    'sense',
#    'shame',
#    'embarrassment',
#    'religion',
#    'freedom',
#    'religious',
#    'platform',
#    'promise',
#    'certainty',
#    'simply',
#    'offer',
#    'faith',
#    'existence',
#    'god',
#    'faith',
#    'religion',
#    'freedom',
#    'take',
#    'high',
#    'virtue',
#    'mankind',
#    'ability',
#    'want',
#    'want',
#    'religion',
#    'freedom',
#    'freedom',
#    'take',
#    'high',
#    'virtue',
#    'mankind',
#    'ability',
#    'want',
#    'want',
#    'give',
#    'discard',
#    'old',
#    'fashion',
#    'sense',
#    'shame',
#    'embarrassment',
#    'religion',
#    'freedom']),
#  ('flyeaglesfly',
#   ['need',
#    'doggone',
#    'go',
#    'mania',
#    'get',
#    'one',
#    'back',
#    'covid',
#    'list',
#    'covid',
#    'take',
#    'come',
#    'room',
#    'covid',
#    'story',
#    'covid',
#    'win',
#    'good',
#    'love',
#    'sander',
#    'hand',
#    'win',
#    'timetable',
#    'return',
#    'unknown',
#    'final',
#    'south',
#    'move',
#    'season',
#    'currently',
#    'final',
#    'spot',
#    'control',
#    'destiny',
#    'wrap',
#    'come',
#    'soon',
#    'control',
#    'destiny',
#    'quest',
#    'currently',
#    'final',
#    'spot',
#    'remain',
#    'touchdown',
#    'reception',
#    'engram',
#    'pat',
#    'good',
#    'phi',
#    'pick',
#    'six',
#    'lead',
#    'regulation',
#    'fat',
#    'man',
#    'touchdown',
#    'alert',
#    'pat',
#    'good',
#    'phi',
#    'score',
#    'phi',
#    'end',
#    'upon',
#    'review',
#    'review',
#    'touchdown',
#    'catch',
#    'phi',
#    'jake',
#    'mike',
#    'jake',
#    'lead',
#    'touchdown',
#    'pat',
#    'good',
#    'phi',
#    'jake',
#    'tie',
#    'another',
#    'amaze',
#    'catch',
#    'jake',
#    'streak',
#    'good',
#    'lead',
#    'field',
#    'goal',
#    'good',
#    'phi',
#    'scoreless',
#    'end',
#    'horrific',
#    'quarter',
#    'football',
#    'less',
#    'ideal',
#    'start',
#    'pas',
#    'incomplete',
#    'dodge',
#    'major',
#    'bullet',
#    'early',
#    'game',
#    'bad',
#    'interception',
#    'first',
#    'drive',
#    'incredible',
#    'field',
#    'position',
#    'interview',
#    'head',
#    'coach',
#    'opening',
#    'touchdown',
#    'ward',
#    'phi',
#    'touchdown',
#    'run',
#    'pat',
#    'good',
#    'phi',
#    'field',
#    'goal',
#    'phi',
#    'touchdown',
#    'run',
#    'pat',
#    'good',
#    'phi',
#    'rush',
#    'season',
#    'touchdown',
#    'run',
#    'pat',
#    'good',
#    'phi',
#    'field',
#    'goal',
#    'phi',
#    'whew',
#    'field',
#    'goal',
#    'good',
#    'phi',
#    'turnover',
#    'quarter',
#    'something',
#    'special',
#    'touchdown',
#    'yard',
#    'run',
#    'pat',
#    'good',
#    'phi',
#    'sigh',
#    'unbelievable',
#    'make',
#    'opinion',
#    'know',
#    'two',
#    'land',
#    'reserve',
#    'covid',
#    'list',
#    'unlikely',
#    'play',
#    'story',
#    'roster',
#    'news',
#    'add',
#    'reserve',
#    'covid',
#    'list',
#    'likely',
#    'unavailable',
#    'tomorrow',
#    'night',
#    'covid',
#    'snap',
#    'count',
#    'threshold',
#    'last',
#    'night',
#    'round',
#    'pick',
#    'overall',
#    'sure',
#    'follow',
#    'late',
#    'news',
#    'follow',
#    'player',
#    'follow',
#    'short',
#    'week',
#    'last',
#    'minute',
#    'story',
#    'follow',
#    'short',
#    'week',
#    'last',
#    'minute',
#    'game',
#    'move',
#    'allow',
#    'time',
#    'recover',
#    'covid',
#    'outbreak',
#    'covid',
#    'outbreak',
#    'football',
#    'team',
#    'covid',
#    'outbreak',
#    'defensive',
#    'story',
#    'omicron',
#    'nominee',
#    'prestigious',
#    'man',
#    'year',
#    'award',
#    'story',
#    'come',
#    'go',
#    'first',
#    'time',
#    'season',
#    'field',
#    'goal',
#    'good',
#    'yard',
#    'phi',
#    'top',
#    'field',
#    'goal',
#    'good',
#    'phi',
#    'top',
#    'call',
#    'boston',
#    'opening',
#    'kickoff',
#    'half',
#    'field',
#    'goal',
#    'good',
#    'phi',
#    'play',
#    'top',
#    'boom',
#    'josh',
#    'swear',
#    'force',
#    'punt',
#    'left',
#    'side',
#    'strong',
#    'side',
#    'stay',
#    'tune',
#    'report',
#    'touchdown',
#    'run',
#    'pat',
#    'good',
#    'phi',
#    'top',
#    'end',
#    'sander',
#    'car',
#    'weekend',
#    'spoke',
#    'cause',
#    'change',
#    'future',
#    'story',
#    'touchdown',
#    'new',
#    'york',
#    'sneak',
#    'pat',
#    'good',
#    'phi',
#    'top',
#    'passing',
#    'drive',
#    'even',
#    'care',
#    'get',
#    'long',
#    'as',
#    'shift',
#    'every',
#    'long',
#    'bring',
#    'back',
#    'quest',
#    'super',
#    'bowl',
#    'enough',
#    'time',
#    'good',
#    'comeback',
#    'thou',
#    'time',
#    'shot',
#    'brutal',
#    'jersey',
#    'tho',
#    'reminder',
#    'quickly',
#    'approach',
#    'please',
#    'pick',
#    'old',
#    'believe',
#    'know',
#    'grown',
#    'still',
#    'believe',
#    'still',
#    'mania',
#    'time',
#    'baby',
#    'one',
#    'team',
#    'really',
#    'need',
#    'big',
#    'impact',
#    'hopefully',
#    'multiple',
#    'high',
#    'draft',
#    'come',
#    'pick',
#    'throw',
#    'start',
#    'new',
#    'season',
#    'see',
#    'look',
#    'new',
#    'coach',
#    'staff',
#    'undoubtedly',
#    'nevertheless',
#    'utter',
#    'three',
#    'hopefully',
#    'win',
#    'streak',
#    'spot',
#    'want',
#    'great',
#    'win']),
#  ('roadtorecovery',
#   ['month',
#    'appointment',
#    'yesterday',
#    'knee',
#    'solid',
#    'much',
#    'muscle',
#    'regression',
#    'feel',
#    'good',
#    'bout',
#    'knee',
#    'get',
#    'look',
#    'muscle',
#    'crack',
#    'scar',
#    'tissue',
#    'still',
#    'annoy',
#    'tho']),
#  ('fantasyfootball',
#   ['feel',
#    'like',
#    'live',
#    'fantasy',
#    'football',
#    'power',
#    'hour',
#    'proudly',
#    'wildcat',
#    'sport',
#    'pub',
#    'week',
#    'fantasy',
#    'football',
#    'advice',
#    'make',
#    'sure',
#    'send',
#    'fantasy',
#    'assume',
#    'able',
#    'make',
#    'speedy',
#    'return',
#    'swift',
#    'see',
#    'would',
#    'call',
#    'generous',
#    'towards',
#    'season',
#    'swift',
#    'able',
#    'adequately',
#    'support',
#    'week',
#    'one',
#    'last',
#    'time',
#    'field',
#    'good',
#    'folk',
#    'twitter',
#    'every',
#    'decision',
#    'week',
#    'need',
#    'help',
#    'time',
#    'great',
#    'treat',
#    'team',
#    'mine',
#    'long',
#    'one',
#    'hour',
#    'whole',
#    'purpose',
#    'help',
#    'get',
#    'championship',
#    'week',
#    'end',
#    'around',
#    'answer',
#    'press',
#    'let',
#    'help',
#    'bring',
#    'home',
#    'title',
#    'championship',
#    'week',
#    'end',
#    'around',
#    'answer',
#    'press',
#    'let',
#    'help',
#    'bring',
#    'home',
#    'title',
#    'last',
#    'time',
#    'season',
#    'check',
#    'tight',
#    'end',
#    'report',
#    'key',
#    'last',
#    'week',
#    'plus',
#    'three',
#    'stream',
#    'help',
#    'land',
#    'title',
#    'week',
#    'last',
#    'time',
#    'season',
#    'check',
#    'tight',
#    'end',
#    'report',
#    'key',
#    'last',
#    'week',
#    'plus',
#    'three',
#    'stream',
#    'help',
#    'land',
#    'title',
#    'week',
#    'category',
#    'eric',
#    'score',
#    'rush',
#    'marquise',
#    'brown',
#    'joe',
#    'flex',
#    'flex',
#    'thanks']),
#  ('btsatamas', ['love']),
#  ('rip',
#   ['three',
#    'last',
#    'forever',
#    'faith',
#    'hope',
#    'love',
#    'love',
#    'cor',
#    'rip',
#    'rip',
#    'rip',
#    'rip',
#    'remember',
#    'probably',
#    'welcome',
#    'party',
#    'rip',
#    'rip',
#    'legend']),
#  ('negativitydefault',
#   ['many',
#    'see',
#    'sit',
#    'right',
#    'wonder',
#    'bring',
#    'capital',
#    'invest',
#    'keep',
#    'come',
#    'struggle',
#    'get',
#    'blind',
#    'many',
#    'see',
#    'sit',
#    'right',
#    'wonder',
#    'bring',
#    'capital',
#    'invest',
#    'keep',
#    'come',
#    'struggle',
#    'get',
#    'blind',
#    'also',
#    'every',
#    'government',
#    'initiative',
#    'met',
#    'despondent',
#    'want',
#    'steal',
#    'rather',
#    'critical',
#    'evaluation',
#    'merit',
#    'demerit',
#    'initiative',
#    'medium',
#    'news',
#    'awash',
#    'response',
#    'ordinary',
#    'help',
#    'salvage',
#    'good',
#    'burning',
#    'building',
#    'someone',
#    'help',
#    'assist',
#    'immediately',
#    'start',
#    'infer',
#    'ulterior',
#    'personal',
#    'loss',
#    'behaviour',
#    'positive',
#    'experience',
#    'relationship',
#    'negative',
#    'attitude',
#    'people',
#    'even',
#    'something',
#    'good',
#    'positive',
#    'unfold',
#    'resist',
#    'urge',
#    'acknowledge']),
#  ('alboforpm', ['way', 'vote', 'alp']),
#  ('climateemergency',
#   ['great', 'holiday', 'look', 'forward', 'stand', 'along', 'side', 'face'])]
# time: 21min 39s (started: 2022-05-03 10:38:10 -04:00)

# %%
# hash_tweet_words_noempty.count()
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# topic = 0
# topic_hash_words_list = topic_words_pd.iloc[:, topic].values.tolist()
# topic_hash_words_list
# Out:
# time: 15 ms (started: 2022-05-03 10:59:50 -04:00)

# %%
# single_word = 'travel'
# temp = hash_tweet_words_noempty.filter(lambda x: single_word in x[1])#singleword in x
# temp.take(5)
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# # group tweet words topics
# topic_words = hash_tweet_words_flat.join(all_topic_hash_words)\
#                     .map(lambda x: (x[1][1], [x[0]]+x[1][0]))
# print(topic_words.take(5))
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# # produce all_topic_hash_words
# all_topic_hash_words = sc.parallelize([])
# for topic in range(num_topic):
#     topic_hash_words_list = topic_words_pd.iloc[:, topic].values.tolist()
#     topic_hash_words_rdd = sc.parallelize(topic_hash_words_list).map(lambda x: (x, 'Topic'+str(topic)))
#     all_topic_hash_words = all_topic_hash_words.union(topic_hash_words_rdd)

# all_topic_hash_words = all_topic_hash_words.cache()
# all_topic_hash_words.take(20)
# Out:
# time: 16 ms (started: 2022-05-03 10:59:50 -04:00)

# %%
# # join topic and words
# topic_words = hash_tweet_words_flat.join(all_topic_hash_words)
# print(topic_words.take(5))
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# # change the form
# topic_words = topic_words.map(lambda x: (x[1][1], [x[0]]+x[1][0]))
# print(topic_words.take(5))
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# # count the frequency
# topic_words_freq = topic_words.flatMap(lambda x: [((x[0],w),1) for w in x[1]]) \
#                 .reduceBy(lambda x1, x2: x1+x2) \
#                 .map(lambda x: (x[0][0], x[0][1], x[1]))
# print(topic_words_freq.take(5))
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# # output in a .csv file
# df_ans = spark.createDataFrame(topic_words_freq, ['topicNum', 'word', 'frequency']).toPandas().to_csv('./result_topic_words_freq.csv', mode='a', index=False, header=False)
# Out:
# time: 0 ns (started: 2022-05-03 10:59:50 -04:00)

# %%
# group tweet words by topics
for topic in range(num_topic):
    topic_hash_words_list = topic_words_pd.iloc[:, topic].values.tolist()
    topic_words = hash_tweet_words_flat.filter(lambda x: x[0] in topic_hash_words_list)\
                    .map(lambda x: (topic, [x[0]]+x[1]))
    
    topic_words_freq = topic_words.flatMap(lambda x: [((x[0],w),1) for w in x[1]]) \
                    .reduceByKey(lambda x1, x2: x1+x2) \
                    .map(lambda x: (x[0][0], x[0][1], x[1]))
#     print(topic_words_freq.take(5))
    # output in a .csv file
    df_ans = spark.createDataFrame(topic_words_freq, ['topicNum', 'word', 'frequency']).toPandas().to_csv('./result_topic_words_freq.csv', mode='a', index=False, header=False)
# Out:
# [(0, 'storm', 1), (0, 'corona', 1), (0, 'eight', 1), (0, 'dramatic', 1), (0, 'take', 7)]
# [(1, 'prayer', 2), (1, 'one', 9), (1, 'unwavering', 1), (1, 'seek', 1), (1, 'product', 1)]
# [(2, 'sometimes', 2), (2, 'must', 2), (2, 'run', 2), (2, 'though', 11), (2, 'work', 7)]
# [(3, 'doggone', 1), (3, 'one', 10), (3, 'back', 8), (3, 'list', 17), (3, 'hand', 5)]
# [(4, 'let', 3), (4, 'right', 9), (4, 'identify', 6), (4, 'stop', 5), (4, 'impunity', 6)]
# [(5, 'steady', 5), (5, 'press', 1), (5, 'release', 1), (5, 'bill', 6), (5, 'carol', 9)]
# [(6, 'supportlarb', 1), (6, 'two', 8), (6, 'form', 1), (6, 'three', 4), (6, 'new', 3)]
# [(7, 'strategy', 1), (7, 'coal', 1), (7, 'sell', 2), (7, 'time', 7), (7, 'add', 1)]
# [(8, 'team', 9), (8, 'ulla', 5), (8, 'open', 6), (8, 'madam', 6), (8, 'water', 2)]
# [(9, 'session', 2), (9, 'follow', 12), (9, 'strategy', 1), (9, 'first', 1), (9, 'technological', 1)]
# [(10, 'yellow', 5), (10, 'beef', 20), (10, 'delivery', 151), (10, 'incredible', 5), (10, 'doorstep', 4)]
# [(11, 'need', 6), (11, 'one', 5), (11, 'back', 4), (11, 'list', 7), (11, 'come', 8)]
# [(12, 'say', 11), (12, 'movie', 6), (12, 'feel', 4), (12, 'marvel', 3), (12, 'runner', 2)]
# [(13, 'food', 2), (13, 'one', 6), (13, 'sir', 1), (13, 'north', 1), (13, 'back', 14)]
# [(14, 'eve', 2), (14, 'omicron', 83), (14, 'change', 4), (14, 'title', 1), (14, 'make', 7)]
# [(15, 'welcome', 1), (15, 'mother', 1), (15, 'splinter', 1), (15, 'brain', 1), (15, 'anniversary', 1)]
# [(16, 'state', 5), (16, 'good', 2), (16, 'earth', 2), (16, 'community', 4), (16, 'native', 1)]
# [(17, 'left', 4), (17, 'still', 4), (17, 'get', 12), (17, 'contact', 1), (17, 'day', 8)]
# [(18, 'year', 33), (18, 'championship', 7), (18, 'possibility', 1), (18, 'stride', 1), (18, 'third', 1)]
# [(19, 'built', 1), (19, 'time', 9), (19, 'sri', 2), (19, 'police', 16), (19, 'forcibly', 3)]
# [(20, 'vimeo', 1), (20, 'dak', 17), (20, 'ready', 1), (20, 'two', 13), (20, 'seed', 1)]
# [(21, 'botanic', 1), (21, 'premium', 2), (21, 'today', 12), (21, 'option', 2), (21, 'one', 50)]
# [(22, 'eagles', 1), (22, 'room', 2), (22, 'story', 6), (22, 'good', 29), (22, 'love', 1)]
# [(23, 'internship', 810), (23, 'less', 22), (23, 'left', 24), (23, 'embark', 9), (23, 'apply', 24)]
# [(24, 'rolltide', 1), (24, 'win', 47), (24, 'hearing', 3), (24, 'say', 2), (24, 'tide', 2)]
# [(25, 'happynewyear', 1), (25, 'wish', 2), (25, 'happy', 7), (25, 'joy', 1), (25, 'swear', 1)]
# [(26, 'week', 1), (26, 'way', 2), (26, 'heart', 3), (26, 'new', 6), (26, 'commerce', 7)]
# [(27, 'analysis', 3), (27, 'bill', 1), (27, 'first', 8), (27, 'activist', 1), (27, 'nearly', 1)]
# [(28, 'fantasyfootball', 1), (28, 'like', 7), (28, 'power', 2), (28, 'pub', 1), (28, 'sure', 2)]
# [(29, 'date', 2), (29, 'star', 2), (29, 'register', 4), (29, 'joyous', 1), (29, 'one', 11)]
# time: 3min 15s (started: 2022-05-03 11:31:01 -04:00)

# %% [markdown]
# ## Find the Topic for a Specific User

# %%
# input the topic words data
topic_words_freq_df = spark.read.csv(
    "result_topic_words_freq.csv", 
    header=False,
    inferSchema = True
)
temp = topic_words_freq_df.select('_c0', '_c1', '_c2')
topic_words_freq = temp.rdd.map(lambda x: [x[1], ('Topic'+str(x[0]), x[2])])
topic_words_freq.take(5)
# Out:
# [['storm', ('Topic0', 1)],
#  ['corona', ('Topic0', 1)],
#  ['eight', ('Topic0', 1)],
#  ['dramatic', ('Topic0', 1)],
#  ['take', ('Topic0', 7)]]
# time: 656 ms (started: 2022-05-03 11:46:29 -04:00)

# %%
# input the history tweets of the specific user
input_user_df = spark.read.csv(
    "input_user_tweets.csv", 
    header=True,
    inferSchema = True
)
temp = input_user_df.select('user_id', 'tweet')
txt_row = temp.rdd
input_user = txt_row.map(lambda x: [str(x[0]), x[1]])
input_user.take(2)
# Out:
# [['215231197', 'Stay gold, Pony Boy.'],
#  ['215231197', 'your tone gives you away.']]
# time: 594 ms (started: 2022-05-03 11:46:30 -04:00)

# %%
# record the userid 
userid = input_user.take(1)[0][0]
print('The user ID is:', userid)

# produce the tweet words list
input_user_clean = input_user.map(lambda x: (x[0], extract_hash_words(easy_clean(x[1]))+advanced_clean(x[1])))\
                                .reduceByKey(lambda x1, x2: x1+x2)
input_words_freq = input_user_clean.flatMap(lambda x: [(w, 1) for w in x[1]])\
                                .reduceByKey(lambda x1, x2: x1+x2) # remove duplicate
input_words_freq.collect()
# Out:
# The user ID is: 215231197
# [('stay', 2),
#  ('gold', 1),
#  ('pony', 1),
#  ('boy', 1),
#  ('tone', 1),
#  ('away', 1),
#  ('unbelieving', 2),
#  ('world', 6),
#  ('nowhere', 1),
#  ('rest', 2),
#  ('weary', 1),
#  ('head', 1),
#  ('jealousy', 1),
#  ('pride', 1),
#  ('discernment', 1),
#  ('refining', 1),
#  ('focus', 1),
#  ('really', 3),
#  ('matter', 1),
#  ('like', 5),
#  ('listen', 1),
#  ('silly', 1),
#  ('actually', 1),
#  ('clean', 3),
#  ('end', 2),
#  ('day', 4),
#  ('anyway', 1),
#  ('year', 1),
#  ('stop', 3),
#  ('hard', 1),
#  ('take', 1),
#  ('fresh', 2),
#  ('laundry', 1),
#  ('machine', 1),
#  ('sit', 1),
#  ('chair', 1),
#  ('untouched', 1),
#  ('marriage', 1),
#  ('paper', 1),
#  ('sign', 2),
#  ('afraid', 2),
#  ('good', 5),
#  ('conscience', 1),
#  ('idolatry', 1),
#  ('spiritual', 1),
#  ('adultery', 1),
#  ('inside', 1),
#  ('job', 1),
#  ('fear', 4),
#  ('wisdom', 2),
#  ('wish', 1),
#  ('see', 4),
#  ('reveal', 2),
#  ('finish', 1),
#  ('want', 10),
#  ('peace', 2),
#  ('understand', 4),
#  ('try', 1),
#  ('humility', 1),
#  ('never', 3),
#  ('meant', 1),
#  ('understood', 1),
#  ('admire', 1),
#  ('wrong', 1),
#  ('side', 2),
#  ('fight', 1),
#  ('right', 5),
#  ('thing', 5),
#  ('homeschooling', 1),
#  ('god', 12),
#  ('need', 3),
#  ('patience', 1),
#  ('religion', 2),
#  ('people', 5),
#  ('hung', 1),
#  ('man', 1),
#  ('tree', 1),
#  ('give', 7),
#  ('offend', 2),
#  ('purple', 1),
#  ('chia', 1),
#  ('pancake', 1),
#  ('full', 3),
#  ('propaganda', 1),
#  ('truth', 7),
#  ('conspiracy', 1),
#  ('err', 1),
#  ('adventure', 1),
#  ('daughter', 1),
#  ('nowadays', 2),
#  ('think', 3),
#  ('funny', 1),
#  ('generation', 1),
#  ('answer', 2),
#  ('everything', 2),
#  ('bend', 1),
#  ('knee', 1),
#  ('ability', 1),
#  ('control', 1),
#  ('superpower', 1),
#  ('cancel', 2),
#  ('culture', 3),
#  ('eldest', 1),
#  ('discover', 1),
#  ('today', 2),
#  ('gosh', 1),
#  ('self', 2),
#  ('condemnation', 1),
#  ('immature', 1),
#  ('suicide', 1),
#  ('go', 1),
#  ('grain', 1),
#  ('truly', 1),
#  ('sad', 2),
#  ('know', 2),
#  ('everyone', 1),
#  ('able', 1),
#  ('discern', 1),
#  ('time', 1),
#  ('eternal', 2),
#  ('life', 5),
#  ('death', 3),
#  ('fun', 1),
#  ('make', 2),
#  ('last', 1),
#  ('true', 3),
#  ('unity', 1),
#  ('diversity', 2),
#  ('tolerate', 1),
#  ('unified', 1),
#  ('stupidity', 2),
#  ('righteousness', 1),
#  ('oxymoron', 1),
#  ('note', 1),
#  ('word', 2),
#  ('moron', 1),
#  ('within', 1),
#  ('church', 1),
#  ('must', 1),
#  ('first', 3),
#  ('turn', 4),
#  ('wicked', 1),
#  ('way', 1),
#  ('bridge', 1),
#  ('say', 3),
#  ('would', 2),
#  ('cross', 1),
#  ('get', 3),
#  ('well', 6),
#  ('back', 3),
#  ('locust', 1),
#  ('eat', 1),
#  ('sent', 1),
#  ('heaven', 1),
#  ('via', 1),
#  ('hell', 2),
#  ('best', 2),
#  ('advice', 1),
#  ('yet', 2),
#  ('discovery', 1),
#  ('innocence', 1),
#  ('loss', 1),
#  ('draw', 1),
#  ('line', 1),
#  ('sand', 1),
#  ('either', 1),
#  ('encourage', 1),
#  ('set', 1),
#  ('free', 4),
#  ('let', 1),
#  ('bread', 1),
#  ('cheek', 2),
#  ('quite', 1),
#  ('often', 2),
#  ('might', 3),
#  ('mean', 1),
#  ('something', 2),
#  ('speak', 3),
#  ('falsehood', 1),
#  ('potential', 1),
#  ('believe', 4),
#  ('keep', 1),
#  ('uncover', 1),
#  ('devil', 1),
#  ('deceiver', 1),
#  ('creative', 1),
#  ('wake', 1),
#  ('sleeper', 1),
#  ('seeker', 1),
#  ('happen', 1),
#  ('parabolic', 1),
#  ('nature', 1),
#  ('build', 1),
#  ('valley', 1),
#  ('built', 1),
#  ('mountain', 1),
#  ('caught', 1),
#  ('emotion', 2),
#  ('beat', 1),
#  ('submission', 1),
#  ('love', 6),
#  ('bind', 1),
#  ('broken', 1),
#  ('power', 1),
#  ('tongue', 1),
#  ('easy', 1),
#  ('do', 1),
#  ('secondhand', 1),
#  ('consider', 1),
#  ('food', 1),
#  ('quality', 1),
#  ('quantity', 1),
#  ('refuse', 1),
#  ('hopelessness', 1),
#  ('morning', 2),
#  ('watch', 3),
#  ('abbey', 1),
#  ('loud', 1),
#  ('work', 2),
#  ('art', 1),
#  ('around', 3),
#  ('even', 1),
#  ('curse', 1),
#  ('sound', 1),
#  ('darn', 1),
#  ('proper', 1),
#  ('dreamt', 1),
#  ('scissors', 1),
#  ('hand', 1),
#  ('haircut', 1),
#  ('instead', 1),
#  ('hate', 2),
#  ('reasonable', 1),
#  ('choose', 1),
#  ('act', 2),
#  ('opposite', 1),
#  ('spirit', 1),
#  ('pray', 2),
#  ('beyond', 1),
#  ('live', 1),
#  ('comfortable', 1),
#  ('hatred', 1),
#  ('united', 1),
#  ('separation', 1),
#  ('stupid', 1),
#  ('buy', 1),
#  ('cheap', 1),
#  ('honor', 1),
#  ('due', 1),
#  ('admit', 1),
#  ('extravagance', 2),
#  ('deserve', 1),
#  ('add', 1),
#  ('lemon', 1),
#  ('oil', 1),
#  ('extra', 1),
#  ('mad', 2),
#  ('person', 1),
#  ('munchies', 1),
#  ('rocky', 1),
#  ('road', 1),
#  ('whisky', 1),
#  ('still', 2),
#  ('miss', 2),
#  ('bowie', 1),
#  ('wow', 1),
#  ('cruel', 1),
#  ('worried', 1),
#  ('start', 1),
#  ('paint', 1),
#  ('prep', 1),
#  ('school', 2),
#  ('excite', 1),
#  ('lot', 1),
#  ('look', 3),
#  ('forward', 2),
#  ('future', 1),
#  ('physical', 1),
#  ('mental', 1),
#  ('emotional', 1),
#  ('junk', 1),
#  ('motto', 1),
#  ('every', 1),
#  ('slate', 1),
#  ('thank', 2),
#  ('addict', 1),
#  ('tomorrow', 1),
#  ('yes', 2),
#  ('ever', 1),
#  ('forget', 1),
#  ('alabaster', 1),
#  ('jar', 1),
#  ('break', 2),
#  ('plant', 1),
#  ('one', 3),
#  ('thousand', 1),
#  ('lalo', 1),
#  ('tradition', 1),
#  ('value', 2),
#  ('high', 1),
#  ('evidence', 1),
#  ('becomes', 1),
#  ('stumble', 1),
#  ('block', 1),
#  ('find', 1),
#  ('jacket', 1),
#  ('essential', 1),
#  ('grow', 2),
#  ('old', 1),
#  ('friend', 2),
#  ('indeed', 1),
#  ('faith', 1),
#  ('divine', 1),
#  ('persuasion', 1),
#  ('translation', 2),
#  ('gain', 1),
#  ('moan', 1),
#  ('milk', 1),
#  ('fish', 1),
#  ('rat', 1),
#  ('canada', 1),
#  ('crisp', 1),
#  ('smell', 1),
#  ('air', 1),
#  ('promise', 1),
#  ('shopping', 1),
#  ('anything', 1),
#  ('big', 1),
#  ('difference', 1),
#  ('throw', 1),
#  ('fist', 1),
#  ('ignorance', 1),
#  ('intelligence', 1),
#  ('silent', 1),
#  ('fault', 1),
#  ('happy', 1),
#  ('benefit', 1),
#  ('relationship', 1),
#  ('without', 1),
#  ('expense', 1),
#  ('covenant', 1),
#  ('hudas', 1),
#  ('remember', 1),
#  ('betrayal', 1),
#  ('come', 1),
#  ('kiss', 1),
#  ('attitude', 1),
#  ('check', 1),
#  ('heart', 3),
#  ('anger', 2),
#  ('gift', 1),
#  ('celebrity', 1),
#  ('exhaust', 1),
#  ('tell', 1),
#  ('judge', 1),
#  ('sohelpmegod', 1),
#  ('call', 1),
#  ('beautiful', 1),
#  ('enemy', 1),
#  ('always', 1),
#  ('backwards', 1),
#  ('press', 1),
#  ('cannot', 1),
#  ('great', 1),
#  ('terrible', 1),
#  ('nothing', 1),
#  ('till', 1),
#  ('virus', 1),
#  ('presence', 2),
#  ('fullness', 1),
#  ('joy', 1),
#  ('hear', 2),
#  ('men', 1),
#  ('king', 1),
#  ('pauper', 1),
#  ('mentality', 1),
#  ('strengthen', 1),
#  ('lovable', 1),
#  ('challenge', 1),
#  ('tender', 1),
#  ('disrupt', 1),
#  ('norm', 1),
#  ('overcome', 1),
#  ('evil', 1),
#  ('peck', 1),
#  ('seldom', 1),
#  ('especially', 1),
#  ('front', 1),
#  ('counter', 1),
#  ('cultural', 1),
#  ('seem', 1),
#  ('senseless', 1),
#  ('another', 1),
#  ('stone', 1)]
# time: 18.6 s (started: 2022-05-03 11:46:30 -04:00)

# %%
# find the topic of each words
input_word_topics = input_words_freq.join(topic_words_freq)\
                                .map(lambda x: (x[0], x[1][1][0], x[1][0]*x[1][1][1]))
input_word_topics.collect()
# Out:
# [('gold', 'Topic14', 3),
#  ('gold', 'Topic26', 2),
#  ('pony', 'Topic8', 1),
#  ('boy', 'Topic0', 2),
#  ('boy', 'Topic6', 3),
#  ('boy', 'Topic12', 1),
#  ('boy', 'Topic13', 2),
#  ('boy', 'Topic15', 1),
#  ('boy', 'Topic18', 2),
#  ('tone', 'Topic2', 2),
#  ('tone', 'Topic6', 1),
#  ('away', 'Topic0', 3),
#  ('away', 'Topic1', 1),
#  ('away', 'Topic3', 2),
#  ('away', 'Topic5', 3),
#  ('away', 'Topic6', 9),
#  ('away', 'Topic11', 1),
#  ('away', 'Topic12', 1),
#  ('away', 'Topic15', 4),
#  ('away', 'Topic16', 2),
#  ('away', 'Topic18', 2),
#  ('away', 'Topic20', 15),
#  ('away', 'Topic22', 2),
#  ('away', 'Topic24', 2),
#  ('away', 'Topic28', 1),
#  ('world', 'Topic0', 36),
#  ('world', 'Topic1', 6),
#  ('world', 'Topic2', 12),
#  ('world', 'Topic4', 6),
#  ('world', 'Topic6', 96),
#  ('world', 'Topic7', 12),
#  ('world', 'Topic8', 54),
#  ('world', 'Topic9', 12),
#  ('world', 'Topic10', 30),
#  ('world', 'Topic11', 24),
#  ('world', 'Topic12', 18),
#  ('world', 'Topic13', 18),
#  ('world', 'Topic14', 12),
#  ('world', 'Topic15', 30),
#  ('world', 'Topic16', 78),
#  ('world', 'Topic17', 114),
#  ('world', 'Topic18', 66),
#  ('world', 'Topic19', 90),
#  ('world', 'Topic21', 24),
#  ('world', 'Topic22', 150),
#  ('world', 'Topic23', 780),
#  ('world', 'Topic24', 18),
#  ('world', 'Topic25', 18),
#  ('world', 'Topic26', 6),
#  ('world', 'Topic27', 18),
#  ('world', 'Topic28', 24),
#  ('world', 'Topic29', 12),
#  ('rest', 'Topic20', 2),
#  ('rest', 'Topic21', 2),
#  ('rest', 'Topic22', 6),
#  ('rest', 'Topic26', 2),
#  ('rest', 'Topic29', 8),
#  ('head', 'Topic0', 3),
#  ('head', 'Topic1', 20),
#  ('head', 'Topic3', 13),
#  ('head', 'Topic6', 13),
#  ('head', 'Topic7', 5),
#  ('head', 'Topic8', 1),
#  ('head', 'Topic9', 2),
#  ('head', 'Topic10', 1),
#  ('head', 'Topic11', 2),
#  ('head', 'Topic12', 1),
#  ('head', 'Topic13', 5),
#  ('head', 'Topic14', 1),
#  ('head', 'Topic16', 5),
#  ('head', 'Topic17', 3),
#  ('head', 'Topic18', 1),
#  ('head', 'Topic19', 2),
#  ('head', 'Topic20', 16),
#  ('head', 'Topic22', 4),
#  ('head', 'Topic23', 15),
#  ('head', 'Topic24', 8),
#  ('head', 'Topic25', 1),
#  ('head', 'Topic28', 2),
#  ('head', 'Topic29', 1),
#  ('pride', 'Topic7', 2),
#  ('pride', 'Topic19', 11),
#  ('pride', 'Topic26', 4),
#  ('discernment', 'Topic1', 1),
#  ('really', 'Topic1', 3),
#  ('really', 'Topic3', 18),
#  ('really', 'Topic5', 3),
#  ('really', 'Topic6', 15),
#  ('really', 'Topic9', 3),
#  ('really', 'Topic10', 6),
#  ('really', 'Topic11', 6),
#  ('really', 'Topic12', 6),
#  ('really', 'Topic14', 3),
#  ('really', 'Topic15', 3),
#  ('really', 'Topic16', 12),
#  ('really', 'Topic17', 18),
#  ('really', 'Topic18', 12),
#  ('really', 'Topic19', 12),
#  ('really', 'Topic22', 15),
#  ('really', 'Topic25', 15),
#  ('really', 'Topic28', 3),
#  ('really', 'Topic29', 3),
#  ('matter', 'Topic1', 1),
#  ('matter', 'Topic8', 4),
#  ('matter', 'Topic16', 12),
#  ('matter', 'Topic17', 2),
#  ('matter', 'Topic19', 1),
#  ('matter', 'Topic20', 2),
#  ('matter', 'Topic23', 26),
#  ('matter', 'Topic28', 1),
#  ('like', 'Topic0', 5),
#  ('like', 'Topic1', 70),
#  ('like', 'Topic2', 25),
#  ('like', 'Topic3', 40),
#  ('like', 'Topic4', 60),
#  ('like', 'Topic6', 50),
#  ('like', 'Topic9', 45),
#  ('like', 'Topic10', 25),
#  ('like', 'Topic11', 10),
#  ('like', 'Topic12', 90),
#  ('like', 'Topic13', 25),
#  ('like', 'Topic14', 20),
#  ('like', 'Topic15', 40),
#  ('like', 'Topic16', 15),
#  ('like', 'Topic17', 90),
#  ('like', 'Topic18', 40),
#  ('like', 'Topic19', 75),
#  ('like', 'Topic20', 15),
#  ('like', 'Topic21', 35),
#  ('like', 'Topic22', 35),
#  ('like', 'Topic23', 80),
#  ('like', 'Topic24', 30),
#  ('like', 'Topic25', 30),
#  ('like', 'Topic28', 35),
#  ('like', 'Topic29', 55),
#  ('end', 'Topic0', 6),
#  ('end', 'Topic1', 12),
#  ('end', 'Topic3', 46),
#  ('end', 'Topic4', 16),
#  ('end', 'Topic6', 2),
#  ('end', 'Topic7', 4),
#  ('end', 'Topic8', 6),
#  ('end', 'Topic9', 22),
#  ('end', 'Topic10', 16),
#  ('end', 'Topic11', 10),
#  ('end', 'Topic12', 8),
#  ('end', 'Topic13', 14),
#  ('end', 'Topic14', 8),
#  ('end', 'Topic15', 2),
#  ('end', 'Topic16', 16),
#  ('end', 'Topic18', 16),
#  ('end', 'Topic19', 12),
#  ('end', 'Topic20', 8),
#  ('end', 'Topic21', 32),
#  ('end', 'Topic22', 18),
#  ('end', 'Topic23', 54),
#  ('end', 'Topic24', 8),
#  ('end', 'Topic25', 8),
#  ('end', 'Topic28', 16),
#  ('end', 'Topic29', 4),
#  ('year', 'Topic0', 32),
#  ('year', 'Topic1', 2),
#  ('year', 'Topic2', 7),
#  ('year', 'Topic3', 7),
#  ('year', 'Topic4', 7),
#  ('year', 'Topic5', 8),
#  ('year', 'Topic6', 6),
#  ('year', 'Topic7', 6),
#  ('year', 'Topic8', 2),
#  ('year', 'Topic9', 23),
#  ('year', 'Topic10', 7),
#  ('year', 'Topic11', 4),
#  ('year', 'Topic12', 4),
#  ('year', 'Topic13', 9),
#  ('year', 'Topic14', 33),
#  ('year', 'Topic15', 5),
#  ('year', 'Topic16', 4),
#  ('year', 'Topic17', 5),
#  ('year', 'Topic18', 33),
#  ('year', 'Topic19', 12),
#  ('year', 'Topic20', 11),
#  ('year', 'Topic21', 9),
#  ('year', 'Topic22', 9),
#  ('year', 'Topic24', 4),
#  ('year', 'Topic25', 14),
#  ('year', 'Topic26', 2),
#  ('year', 'Topic27', 7),
#  ('year', 'Topic28', 5),
#  ('year', 'Topic29', 3),
#  ('stop', 'Topic0', 3),
#  ('stop', 'Topic1', 6),
#  ('stop', 'Topic2', 3),
#  ('stop', 'Topic3', 6),
#  ('stop', 'Topic4', 15),
#  ('stop', 'Topic6', 12),
#  ('stop', 'Topic8', 21),
#  ('stop', 'Topic10', 6),
#  ('stop', 'Topic11', 3),
#  ('stop', 'Topic12', 3),
#  ('stop', 'Topic14', 3),
#  ('stop', 'Topic16', 9),
#  ('stop', 'Topic17', 9),
#  ('stop', 'Topic18', 12),
#  ('stop', 'Topic19', 15),
#  ('stop', 'Topic20', 3),
#  ('stop', 'Topic21', 72),
#  ('stop', 'Topic22', 36),
#  ('stop', 'Topic24', 6),
#  ('stop', 'Topic25', 3),
#  ('stop', 'Topic27', 3),
#  ('stop', 'Topic28', 3),
#  ('stop', 'Topic29', 3),
#  ('take', 'Topic0', 7),
#  ('take', 'Topic1', 10),
#  ('take', 'Topic2', 2),
#  ('take', 'Topic3', 6),
#  ('take', 'Topic4', 2),
#  ('take', 'Topic5', 4),
#  ('take', 'Topic6', 27),
#  ('take', 'Topic7', 2),
#  ('take', 'Topic8', 1),
#  ('take', 'Topic9', 9),
#  ('take', 'Topic10', 10),
#  ('take', 'Topic11', 19),
#  ('take', 'Topic12', 12),
#  ('take', 'Topic13', 7),
#  ('take', 'Topic14', 18),
#  ('take', 'Topic15', 8),
#  ('take', 'Topic16', 3),
#  ('take', 'Topic17', 4),
#  ('take', 'Topic18', 24),
#  ('take', 'Topic19', 12),
#  ('take', 'Topic20', 36),
#  ('take', 'Topic21', 10),
#  ('take', 'Topic22', 16),
#  ('take', 'Topic23', 42),
#  ('take', 'Topic24', 2),
#  ('take', 'Topic25', 18),
#  ('take', 'Topic27', 4),
#  ('take', 'Topic28', 14),
#  ('take', 'Topic29', 15),
#  ('machine', 'Topic15', 1),
#  ('machine', 'Topic17', 2),
#  ('machine', 'Topic18', 2),
#  ('machine', 'Topic27', 3),
#  ('chair', 'Topic5', 3),
#  ('chair', 'Topic15', 1),
#  ('chair', 'Topic17', 5),
#  ('chair', 'Topic19', 2),
#  ('marriage', 'Topic4', 2),
#  ('marriage', 'Topic17', 2),
#  ('marriage', 'Topic19', 20),
#  ('marriage', 'Topic27', 2),
#  ('sign', 'Topic2', 2),
#  ('sign', 'Topic7', 2),
#  ('sign', 'Topic17', 4),
#  ('peace', 'Topic28', 4),
#  ('understand', 'Topic3', 12),
#  ('understand', 'Topic4', 8),
#  ('understand', 'Topic9', 8),
#  ('understand', 'Topic10', 8),
#  ('understand', 'Topic12', 4),
#  ('understand', 'Topic13', 12),
#  ('understand', 'Topic15', 4),
#  ('understand', 'Topic17', 20),
#  ('understand', 'Topic18', 8),
#  ('understand', 'Topic22', 8),
#  ('understand', 'Topic25', 4),
#  ('try', 'Topic0', 2),
#  ('try', 'Topic1', 1),
#  ('try', 'Topic2', 7),
#  ('try', 'Topic3', 2),
#  ('try', 'Topic4', 1),
#  ('try', 'Topic10', 4),
#  ('try', 'Topic12', 10),
#  ('try', 'Topic13', 3),
#  ('try', 'Topic14', 1),
#  ('try', 'Topic15', 2),
#  ('try', 'Topic16', 1),
#  ('try', 'Topic17', 1),
#  ('try', 'Topic18', 6),
#  ('try', 'Topic19', 2),
#  ('try', 'Topic20', 3),
#  ('try', 'Topic21', 1),
#  ('try', 'Topic22', 3),
#  ('try', 'Topic23', 13),
#  ('try', 'Topic24', 1),
#  ('try', 'Topic25', 3),
#  ('try', 'Topic27', 2),
#  ('try', 'Topic28', 3),
#  ('try', 'Topic29', 10),
#  ('never', 'Topic0', 3),
#  ('never', 'Topic1', 6),
#  ('never', 'Topic3', 9),
#  ('never', 'Topic6', 21),
#  ('never', 'Topic8', 21),
#  ('never', 'Topic9', 3),
#  ('never', 'Topic10', 12),
#  ('never', 'Topic11', 3),
#  ('never', 'Topic12', 6),
#  ('never', 'Topic14', 3),
#  ('never', 'Topic15', 6),
#  ('never', 'Topic16', 6),
#  ('never', 'Topic17', 15),
#  ('never', 'Topic18', 12),
#  ('never', 'Topic19', 3),
#  ('never', 'Topic20', 3),
#  ('never', 'Topic21', 12),
#  ('never', 'Topic22', 33),
#  ('never', 'Topic23', 90),
#  ('never', 'Topic25', 6),
#  ('never', 'Topic28', 6),
#  ('never', 'Topic29', 9),
#  ('understood', 'Topic17', 1),
#  ('fight', 'Topic4', 9),
#  ('fight', 'Topic6', 1),
#  ('fight', 'Topic8', 6),
#  ('fight', 'Topic13', 2),
#  ('fight', 'Topic17', 2),
#  ('fight', 'Topic19', 8),
#  ('fight', 'Topic20', 3),
#  ('fight', 'Topic22', 6),
#  ('fight', 'Topic23', 15),
#  ('fight', 'Topic24', 1),
#  ('fight', 'Topic29', 1),
#  ('right', 'Topic0', 10),
#  ('right', 'Topic2', 5),
#  ('right', 'Topic3', 10),
#  ('right', 'Topic4', 45),
#  ('right', 'Topic5', 155),
#  ('right', 'Topic6', 60),
#  ('right', 'Topic7', 5),
#  ('right', 'Topic8', 5),
#  ('right', 'Topic9', 110),
#  ('right', 'Topic12', 35),
#  ('right', 'Topic13', 10),
#  ('right', 'Topic15', 10),
#  ('right', 'Topic16', 5),
#  ('right', 'Topic18', 20),
#  ('right', 'Topic19', 20),
#  ('right', 'Topic20', 5),
#  ('right', 'Topic21', 160),
#  ('right', 'Topic22', 15),
#  ('right', 'Topic23', 75),
#  ('right', 'Topic24', 5),
#  ('able', 'Topic4', 1),
#  ('able', 'Topic6', 2),
#  ('able', 'Topic10', 1),
#  ('able', 'Topic11', 1),
#  ('able', 'Topic12', 1),
#  ('able', 'Topic14', 1),
#  ('able', 'Topic15', 1),
#  ('able', 'Topic18', 1),
#  ('able', 'Topic19', 2),
#  ('able', 'Topic23', 1),
#  ('able', 'Topic25', 1),
#  ('able', 'Topic28', 4),
#  ('able', 'Topic29', 1),
#  ('make', 'Topic0', 22),
#  ('make', 'Topic1', 12),
#  ('make', 'Topic2', 28),
#  ('make', 'Topic3', 18),
#  ('make', 'Topic4', 12),
#  ('make', 'Topic5', 22),
#  ('make', 'Topic6', 18),
#  ('make', 'Topic7', 4),
#  ('make', 'Topic9', 62),
#  ('make', 'Topic10', 20),
#  ('make', 'Topic11', 8),
#  ('make', 'Topic12', 16),
#  ('make', 'Topic13', 12),
#  ('make', 'Topic14', 14),
#  ('make', 'Topic15', 18),
#  ('make', 'Topic17', 12),
#  ('make', 'Topic18', 24),
#  ('make', 'Topic19', 24),
#  ('make', 'Topic20', 4),
#  ('make', 'Topic21', 60),
#  ('make', 'Topic22', 24),
#  ('make', 'Topic23', 48),
#  ('make', 'Topic24', 10),
#  ('make', 'Topic25', 8),
#  ('make', 'Topic26', 2),
#  ('make', 'Topic27', 10),
#  ('make', 'Topic28', 18),
#  ('make', 'Topic29', 26),
#  ('last', 'Topic0', 2),
#  ('last', 'Topic1', 4),
#  ('last', 'Topic2', 4),
#  ('last', 'Topic3', 16),
#  ('last', 'Topic4', 2),
#  ('last', 'Topic5', 4),
#  ('last', 'Topic6', 6),
#  ('last', 'Topic8', 3),
#  ('last', 'Topic9', 1),
#  ('last', 'Topic10', 2),
#  ('last', 'Topic11', 3),
#  ('last', 'Topic12', 1),
#  ('last', 'Topic13', 4),
#  ('last', 'Topic14', 5),
#  ('last', 'Topic15', 2),
#  ('last', 'Topic16', 2),
#  ('last', 'Topic17', 3),
#  ('last', 'Topic18', 6),
#  ('last', 'Topic19', 2),
#  ('last', 'Topic20', 1),
#  ('last', 'Topic21', 1),
#  ('last', 'Topic22', 16),
#  ('last', 'Topic23', 15),
#  ('last', 'Topic24', 4),
#  ('last', 'Topic25', 1),
#  ('last', 'Topic26', 1),
#  ('last', 'Topic27', 1),
#  ('last', 'Topic28', 8),
#  ('last', 'Topic29', 46),
#  ('true', 'Topic0', 6),
#  ('true', 'Topic1', 3),
#  ('true', 'Topic2', 3),
#  ('true', 'Topic8', 9),
#  ('true', 'Topic10', 21),
#  ('true', 'Topic11', 3),
#  ('true', 'Topic12', 3),
#  ('true', 'Topic14', 3),
#  ('true', 'Topic18', 6),
#  ('true', 'Topic19', 3),
#  ('true', 'Topic21', 3),
#  ('true', 'Topic25', 3),
#  ('true', 'Topic27', 72),
#  ('true', 'Topic28', 6),
#  ('true', 'Topic29', 3),
#  ('must', 'Topic0', 6),
#  ('must', 'Topic1', 1),
#  ('must', 'Topic2', 2),
#  ('must', 'Topic4', 14),
#  ('must', 'Topic6', 3),
#  ('must', 'Topic8', 1),
#  ('must', 'Topic9', 3),
#  ('must', 'Topic10', 3),
#  ('must', 'Topic11', 1),
#  ('must', 'Topic12', 1),
#  ('must', 'Topic14', 1),
#  ('must', 'Topic15', 4),
#  ('must', 'Topic17', 12),
#  ('must', 'Topic18', 5),
#  ('must', 'Topic19', 9),
#  ('must', 'Topic20', 3),
#  ('must', 'Topic21', 5),
#  ('must', 'Topic22', 7),
#  ('must', 'Topic23', 15),
#  ('must', 'Topic25', 1),
#  ('must', 'Topic27', 4),
#  ('must', 'Topic28', 3),
#  ('must', 'Topic29', 1),
#  ('turn', 'Topic4', 4),
#  ('turn', 'Topic6', 28),
#  ('turn', 'Topic7', 8),
#  ('turn', 'Topic8', 8),
#  ('turn', 'Topic11', 24),
#  ('turn', 'Topic12', 4),
#  ('turn', 'Topic16', 4),
#  ('turn', 'Topic17', 4),
#  ('turn', 'Topic18', 16),
#  ('turn', 'Topic20', 12),
#  ('turn', 'Topic23', 60),
#  ('turn', 'Topic27', 4),
#  ('turn', 'Topic28', 8),
#  ('turn', 'Topic29', 8),
#  ('way', 'Topic0', 2),
#  ('way', 'Topic1', 1),
#  ('way', 'Topic2', 5),
#  ('way', 'Topic3', 3),
#  ('way', 'Topic4', 1),
#  ('way', 'Topic5', 9),
#  ('way', 'Topic6', 17),
#  ('way', 'Topic8', 1),
#  ('way', 'Topic9', 1),
#  ('way', 'Topic10', 5),
#  ('way', 'Topic11', 1),
#  ('way', 'Topic12', 1),
#  ('way', 'Topic13', 4),
#  ('way', 'Topic14', 2),
#  ('way', 'Topic15', 7),
#  ('way', 'Topic16', 1),
#  ('way', 'Topic17', 15),
#  ('way', 'Topic18', 8),
#  ('way', 'Topic19', 6),
#  ('way', 'Topic20', 2),
#  ('way', 'Topic21', 10),
#  ('way', 'Topic22', 6),
#  ('way', 'Topic24', 2),
#  ('way', 'Topic25', 3),
#  ('way', 'Topic26', 2),
#  ('way', 'Topic27', 3),
#  ('way', 'Topic28', 2),
#  ('way', 'Topic29', 16),
#  ('bridge', 'Topic12', 1),
#  ('bridge', 'Topic17', 3),
#  ('bridge', 'Topic19', 1),
#  ('bridge', 'Topic20', 3),
#  ('bridge', 'Topic21', 3),
#  ('say', 'Topic0', 12),
#  ('say', 'Topic1', 9),
#  ('say', 'Topic2', 6),
#  ('say', 'Topic6', 30),
#  ('say', 'Topic8', 15),
#  ('say', 'Topic9', 21),
#  ('say', 'Topic10', 27),
#  ('say', 'Topic11', 9),
#  ('say', 'Topic12', 33),
#  ('say', 'Topic13', 3),
#  ('say', 'Topic14', 9),
#  ('say', 'Topic15', 36),
#  ('say', 'Topic16', 12),
#  ('say', 'Topic17', 330),
#  ('say', 'Topic18', 30),
#  ('say', 'Topic19', 72),
#  ('say', 'Topic20', 132),
#  ('say', 'Topic21', 9),
#  ('say', 'Topic22', 6),
#  ('say', 'Topic24', 6),
#  ('say', 'Topic25', 21),
#  ('say', 'Topic26', 3),
#  ('say', 'Topic27', 6),
#  ('say', 'Topic28', 12),
#  ('say', 'Topic29', 27),
#  ('would', 'Topic1', 28),
#  ('would', 'Topic2', 12),
#  ('would', 'Topic3', 16),
#  ('would', 'Topic4', 2),
#  ('would', 'Topic5', 10),
#  ('would', 'Topic6', 2),
#  ('would', 'Topic7', 6),
#  ('would', 'Topic8', 2),
#  ('would', 'Topic10', 14),
#  ('would', 'Topic11', 4),
#  ('would', 'Topic12', 6),
#  ('would', 'Topic14', 8),
#  ('would', 'Topic15', 6),
#  ('would', 'Topic17', 14),
#  ('would', 'Topic18', 8),
#  ('would', 'Topic19', 24),
#  ('would', 'Topic20', 2),
#  ('would', 'Topic21', 16),
#  ('would', 'Topic22', 8),
#  ('would', 'Topic24', 8),
#  ('would', 'Topic25', 8),
#  ('would', 'Topic27', 2),
#  ('would', 'Topic28', 18),
#  ('would', 'Topic29', 6),
#  ('cross', 'Topic0', 1),
#  ('cross', 'Topic2', 1),
#  ('cross', 'Topic15', 1),
#  ('cross', 'Topic17', 4),
#  ('cross', 'Topic19', 3),
#  ('cross', 'Topic22', 1),
#  ('cross', 'Topic23', 2),
#  ('cross', 'Topic24', 1),
#  ('cross', 'Topic28', 1),
#  ('sent', 'Topic9', 2),
#  ('sent', 'Topic13', 1),
#  ('sent', 'Topic14', 1),
#  ('sent', 'Topic15', 1),
#  ('sent', 'Topic16', 3),
#  ('sent', 'Topic19', 2),
#  ('sent', 'Topic21', 2),
#  ('sent', 'Topic28', 2),
#  ('via', 'Topic0', 13),
#  ('via', 'Topic1', 6),
#  ('via', 'Topic2', 1),
#  ('via', 'Topic4', 2),
#  ('via', 'Topic9', 2),
#  ('via', 'Topic10', 224),
#  ('via', 'Topic11', 4),
#  ('via', 'Topic12', 4),
#  ('via', 'Topic14', 4),
#  ('via', 'Topic17', 1),
#  ('via', 'Topic18', 4),
#  ('via', 'Topic19', 6),
#  ('via', 'Topic20', 5),
#  ('via', 'Topic21', 1),
#  ('via', 'Topic22', 1),
#  ('via', 'Topic24', 1),
#  ('via', 'Topic25', 4),
#  ('via', 'Topic27', 1),
#  ('via', 'Topic28', 4),
#  ('via', 'Topic29', 4),
#  ('best', 'Topic0', 28),
#  ('best', 'Topic1', 6),
#  ('best', 'Topic2', 6),
#  ('best', 'Topic3', 6),
#  ('best', 'Topic6', 10),
#  ('best', 'Topic7', 2),
#  ('best', 'Topic9', 4),
#  ('best', 'Topic10', 4),
#  ('best', 'Topic11', 2),
#  ('best', 'Topic12', 18),
#  ('best', 'Topic13', 16),
#  ('best', 'Topic14', 22),
#  ('best', 'Topic15', 8),
#  ('best', 'Topic16', 2),
#  ('best', 'Topic17', 4),
#  ('best', 'Topic18', 14),
#  ('best', 'Topic19', 4),
#  ('best', 'Topic20', 10),
#  ('best', 'Topic21', 30),
#  ('best', 'Topic22', 10),
#  ('best', 'Topic23', 22),
#  ('best', 'Topic24', 2),
#  ('best', 'Topic25', 20),
#  ('best', 'Topic26', 4),
#  ('best', 'Topic27', 4),
#  ('best', 'Topic29', 92),
#  ('yet', 'Topic0', 4),
#  ('yet', 'Topic2', 2),
#  ('yet', 'Topic4', 12),
#  ('yet', 'Topic8', 2),
#  ('yet', 'Topic12', 4),
#  ('yet', 'Topic17', 2),
#  ('yet', 'Topic18', 2),
#  ('yet', 'Topic19', 6),
#  ('yet', 'Topic20', 8),
#  ('yet', 'Topic21', 10),
#  ('yet', 'Topic22', 2),
#  ('yet', 'Topic23', 2),
#  ('yet', 'Topic27', 2),
#  ('yet', 'Topic28', 4),
#  ('yet', 'Topic29', 4),
#  ('loss', 'Topic3', 2),
#  ('loss', 'Topic6', 1),
#  ('loss', 'Topic13', 1),
#  ('loss', 'Topic20', 2),
#  ('loss', 'Topic21', 6),
#  ('loss', 'Topic22', 5),
#  ('loss', 'Topic29', 6),
#  ('draw', 'Topic0', 1),
#  ('draw', 'Topic2', 1),
#  ('draw', 'Topic13', 5),
#  ('draw', 'Topic17', 1),
#  ('draw', 'Topic19', 2),
#  ('draw', 'Topic23', 1),
#  ('line', 'Topic0', 1),
#  ('line', 'Topic2', 4),
#  ('line', 'Topic9', 6),
#  ('line', 'Topic15', 3),
#  ('line', 'Topic17', 4),
#  ('line', 'Topic19', 2),
#  ('line', 'Topic20', 5),
#  ('line', 'Topic26', 1),
#  ('set', 'Topic1', 1),
#  ('set', 'Topic2', 5),
#  ('set', 'Topic5', 9),
#  ('set', 'Topic6', 7),
#  ('set', 'Topic9', 3),
#  ('set', 'Topic13', 2),
#  ('set', 'Topic16', 13),
#  ('set', 'Topic17', 2),
#  ('set', 'Topic18', 3),
#  ('set', 'Topic19', 3),
#  ('set', 'Topic20', 14),
#  ('set', 'Topic21', 20),
#  ('set', 'Topic22', 7),
#  ('set', 'Topic27', 1),
#  ('set', 'Topic29', 2),
#  ('free', 'Topic0', 8),
#  ('free', 'Topic2', 4),
#  ('free', 'Topic3', 4),
#  ('free', 'Topic4', 4),
#  ('free', 'Topic6', 12),
#  ('free', 'Topic8', 4),
#  ('free', 'Topic9', 4),
#  ('free', 'Topic15', 16),
#  ('free', 'Topic16', 8),
#  ('free', 'Topic19', 4),
#  ('free', 'Topic21', 60),
#  ('free', 'Topic22', 4),
#  ('free', 'Topic24', 4),
#  ('free', 'Topic26', 12),
#  ('free', 'Topic28', 4),
#  ('free', 'Topic29', 16),
#  ('let', 'Topic0', 3),
#  ('let', 'Topic1', 2),
#  ('let', 'Topic2', 2),
#  ('let', 'Topic3', 3),
#  ('let', 'Topic4', 3),
#  ('let', 'Topic5', 4),
#  ('let', 'Topic6', 17),
#  ('let', 'Topic9', 1),
#  ('let', 'Topic10', 1),
#  ('let', 'Topic11', 8),
#  ('let', 'Topic12', 27),
#  ('let', 'Topic13', 2),
#  ('let', 'Topic14', 2),
#  ('let', 'Topic15', 6),
#  ('let', 'Topic16', 1),
#  ('let', 'Topic17', 2),
#  ('let', 'Topic18', 5),
#  ('let', 'Topic19', 1),
#  ('let', 'Topic21', 32),
#  ('let', 'Topic22', 24),
#  ('let', 'Topic23', 24),
#  ('let', 'Topic24', 1),
#  ('let', 'Topic25', 5),
#  ('let', 'Topic26', 6),
#  ('let', 'Topic27', 159),
#  ('let', 'Topic28', 3),
#  ('let', 'Topic29', 1),
#  ('bread', 'Topic10', 1),
#  ('bread', 'Topic15', 1),
#  ('bread', 'Topic29', 2),
#  ('mean', 'Topic2', 4),
#  ('mean', 'Topic3', 1),
#  ('mean', 'Topic12', 1),
#  ('mean', 'Topic18', 1),
#  ('mean', 'Topic21', 1),
#  ('mean', 'Topic22', 1),
#  ('mean', 'Topic29', 2),
#  ('something', 'Topic0', 2),
#  ('something', 'Topic1', 6),
#  ('something', 'Topic2', 2),
#  ('something', 'Topic3', 10),
#  ('something', 'Topic4', 2),
#  ('something', 'Topic10', 2),
#  ('something', 'Topic11', 4),
#  ('something', 'Topic12', 4),
#  ('something', 'Topic14', 2),
#  ('something', 'Topic15', 2),
#  ('something', 'Topic18', 2),
#  ('something', 'Topic19', 4),
#  ('something', 'Topic22', 6),
#  ('something', 'Topic23', 32),
#  ('something', 'Topic25', 6),
#  ('something', 'Topic26', 2),
#  ('something', 'Topic28', 4),
#  ('something', 'Topic29', 8),
#  ('speak', 'Topic9', 3),
#  ('speak', 'Topic17', 6),
#  ('speak', 'Topic19', 12),
#  ('speak', 'Topic21', 9),
#  ...]
# time: 2.84 s (started: 2022-05-03 11:46:49 -04:00)

# %%
# count and sort the number of related topics
input_related_topics = input_word_topics.map(lambda x: (x[1], x[2]))\
                                        .reduceByKey(lambda x1, x2: x1+x2)\
                                        .sortBy(lambda x: x[1], ascending=False)
input_related_topics.collect()
# Out:
# [('Topic23', 4501),
#  ('Topic2', 3601),
#  ('Topic21', 2636),
#  ('Topic27', 2340),
#  ('Topic22', 2035),
#  ('Topic6', 1970),
#  ('Topic5', 1795),
#  ('Topic29', 1787),
#  ('Topic19', 1762),
#  ('Topic20', 1693),
#  ('Topic17', 1604),
#  ('Topic18', 1557),
#  ('Topic3', 1475),
#  ('Topic10', 1461),
#  ('Topic12', 1160),
#  ('Topic15', 1091),
#  ('Topic0', 1034),
#  ('Topic11', 1028),
#  ('Topic1', 1024),
#  ('Topic25', 978),
#  ('Topic28', 977),
#  ('Topic13', 853),
#  ('Topic9', 847),
#  ('Topic14', 793),
#  ('Topic8', 779),
#  ('Topic4', 760),
#  ('Topic16', 707),
#  ('Topic24', 559),
#  ('Topic7', 329),
#  ('Topic26', 188)]
# time: 4.67 s (started: 2022-05-03 11:46:52 -04:00)

# %%
print('The most relevant topic is:', input_related_topics.take(1)[0][0])
# Out:
# The most relevant topic is: Topic23
# time: 453 ms (started: 2022-05-03 11:46:56 -04:00)

# %%
topic_word_top5 = pd.read_csv('result_topic_words.csv')
# Out:
# time: 16 ms (started: 2022-05-05 16:53:51 -04:00)

# %%
topic_word_top5_list = topic_word_top5[input_related_topics.take(1)[0][0]][:5].values.tolist()
# Out:
# time: 453 ms (started: 2022-05-05 16:56:26 -04:00)

# %%
topic_word_top5_list
# Out:
# ['ibs', 'ibsat', 'mba', 'mbacampus', 'bestcollege']
# time: 0 ns (started: 2022-05-05 16:56:34 -04:00)
